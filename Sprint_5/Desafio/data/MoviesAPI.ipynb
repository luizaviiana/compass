# %% [markdown]
# ###  Análise API
# ---

# %%
import requests
import pandas as pd
import time
import os
from dotenv import load_dotenv

load_dotenv()
bearer_token = os.getenv("TMDB_BEARER_TOKEN")

headers = {
    "Authorization": f"Bearer {bearer_token}",
    "Content-Type": "application/json;charset=utf-8"
}

def buscar_filmes_guerra_com_filtros():
    url_base = "https://api.themoviedb.org/3/discover/movie"
    pagina = 1
    filmes = []

    while True:
        params = {
            "language": "pt-BR",
            "with_genres": 10752,            
            "sort_by": "popularity.desc",
            "vote_count.gte": 100,
            "vote_average.gte": 6.0,
            "page": pagina,
            "primary_release_date.gte": "1950-01-01"     
        }

        response = requests.get(url_base, headers=headers, params=params)

        if response.status_code != 200:
            print(f"Erro ao buscar página {pagina}: {response.status_code}")
            break

        dados = response.json()
        resultados = dados.get("results", [])
        if not resultados:
            break

        filmes.extend(resultados)
        print(f"Página {pagina} coletada com {len(resultados)} filmes.")
        pagina += 1

        if pagina > dados.get("total_pages", 1):
            break

        time.sleep(0.25)  

    return [filme['id'] for filme in filmes]

def buscar_detalhes_filme(id_tmdb):
    url = f"https://api.themoviedb.org/3/movie/{id_tmdb}?language=pt-BR&append_to_response=credits,keywords,release_dates"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Erro ao buscar detalhes do filme ID {id_tmdb}")
        return None

print("Buscando filmes de guerra a partir de 1950 com filtros de nota e votos...")
ids_filmes = buscar_filmes_guerra_com_filtros()
print(f" Total de filmes encontrados: {len(ids_filmes)}")

dados_completos = []
for idx, id_filme in enumerate(ids_filmes):
    print(f" Buscando detalhes do filme {idx+1}/{len(ids_filmes)} - ID: {id_filme}")
    dados = buscar_detalhes_filme(id_filme)
    if dados:
        dados_completos.append(dados)
    time.sleep(0.25)

df_filmes = pd.json_normalize(dados_completos)
df_filmes.to_csv("filmes_guerra_detalhes.csv", index=False, encoding='utf-8-sig')

print(" Arquivo salvo como 'filmes_guerra_detalhes.csv'")
# Out:
# 🔎 Buscando filmes de guerra a partir de 1950 com filtros de nota e votos...
# Página 1 coletada com 20 filmes.
# Página 2 coletada com 20 filmes.
# Página 3 coletada com 20 filmes.
# Página 4 coletada com 20 filmes.
# Página 5 coletada com 20 filmes.
# Página 6 coletada com 20 filmes.
# Página 7 coletada com 20 filmes.
# Página 8 coletada com 20 filmes.
# Página 9 coletada com 20 filmes.
# Página 10 coletada com 20 filmes.
# Página 11 coletada com 20 filmes.
# Página 12 coletada com 20 filmes.
# Página 13 coletada com 20 filmes.
# Página 14 coletada com 20 filmes.
# Página 15 coletada com 20 filmes.
# Página 16 coletada com 20 filmes.
# Página 17 coletada com 20 filmes.
# Página 18 coletada com 20 filmes.
# Página 19 coletada com 20 filmes.
# Página 20 coletada com 20 filmes.
# Página 21 coletada com 20 filmes.
# Página 22 coletada com 20 filmes.
# Página 23 coletada com 20 filmes.
# Página 24 coletada com 20 filmes.
# Página 25 coletada com 20 filmes.
# Página 26 coletada com 20 filmes.
# Página 27 coletada com 20 filmes.
# Página 28 coletada com 20 filmes.
# Página 29 coletada com 14 filmes.
# ✅ Total de filmes encontrados: 574
# 🔄 Buscando detalhes do filme 1/574 - ID: 1241436
# 🔄 Buscando detalhes do filme 2/574 - ID: 281338
# 🔄 Buscando detalhes do filme 3/574 - ID: 515001
# 🔄 Buscando detalhes do filme 4/574 - ID: 324786
# 🔄 Buscando detalhes do filme 5/574 - ID: 927342
# 🔄 Buscando detalhes do filme 6/574 - ID: 1043905
# 🔄 Buscando detalhes do filme 7/574 - ID: 16869
# 🔄 Buscando detalhes do filme 8/574 - ID: 929590
# 🔄 Buscando detalhes do filme 9/574 - ID: 792
# 🔄 Buscando detalhes do filme 10/574 - ID: 228150
# 🔄 Buscando detalhes do filme 11/574 - ID: 424
# 🔄 Buscando detalhes do filme 12/574 - ID: 855
# 🔄 Buscando detalhes do filme 13/574 - ID: 857
# 🔄 Buscando detalhes do filme 14/574 - ID: 1495
# 🔄 Buscando detalhes do filme 15/574 - ID: 753342
# 🔄 Buscando detalhes do filme 16/574 - ID: 652
# 🔄 Buscando detalhes do filme 17/574 - ID: 882569
# 🔄 Buscando detalhes do filme 18/574 - ID: 17835
# 🔄 Buscando detalhes do filme 19/574 - ID: 799583
# 🔄 Buscando detalhes do filme 20/574 - ID: 197
# 🔄 Buscando detalhes do filme 21/574 - ID: 966220
# 🔄 Buscando detalhes do filme 22/574 - ID: 1368
# 🔄 Buscando detalhes do filme 23/574 - ID: 1417
# 🔄 Buscando detalhes do filme 24/574 - ID: 840326
# 🔄 Buscando detalhes do filme 25/574 - ID: 1271
# 🔄 Buscando detalhes do filme 26/574 - ID: 190859
# 🔄 Buscando detalhes do filme 27/574 - ID: 14574
# 🔄 Buscando detalhes do filme 28/574 - ID: 516486
# 🔄 Buscando detalhes do filme 29/574 - ID: 600
# 🔄 Buscando detalhes do filme 30/574 - ID: 597922
# 🔄 Buscando detalhes do filme 31/574 - ID: 1369
# 🔄 Buscando detalhes do filme 32/574 - ID: 7445
# 🔄 Buscando detalhes do filme 33/574 - ID: 530915
# 🔄 Buscando detalhes do filme 34/574 - ID: 7555
# 🔄 Buscando detalhes do filme 35/574 - ID: 53182
# 🔄 Buscando detalhes do filme 36/574 - ID: 616
# 🔄 Buscando detalhes do filme 37/574 - ID: 423
# 🔄 Buscando detalhes do filme 38/574 - ID: 567189
# 🔄 Buscando detalhes do filme 39/574 - ID: 300671
# 🔄 Buscando detalhes do filme 40/574 - ID: 676
# 🔄 Buscando detalhes do filme 41/574 - ID: 1222248
# 🔄 Buscando detalhes do filme 42/574 - ID: 28
# 🔄 Buscando detalhes do filme 43/574 - ID: 205596
# 🔄 Buscando detalhes do filme 44/574 - ID: 374720
# 🔄 Buscando detalhes do filme 45/574 - ID: 49046
# 🔄 Buscando detalhes do filme 46/574 - ID: 46738
# 🔄 Buscando detalhes do filme 47/574 - ID: 2024
# 🔄 Buscando detalhes do filme 48/574 - ID: 853
# 🔄 Buscando detalhes do filme 49/574 - ID: 856289
# 🔄 Buscando detalhes do filme 50/574 - ID: 467244
# 🔄 Buscando detalhes do filme 51/574 - ID: 969492
# 🔄 Buscando detalhes do filme 52/574 - ID: 9567
# 🔄 Buscando detalhes do filme 53/574 - ID: 2253
# 🔄 Buscando detalhes do filme 54/574 - ID: 7446
# 🔄 Buscando detalhes do filme 55/574 - ID: 5925
# 🔄 Buscando detalhes do filme 56/574 - ID: 967
# 🔄 Buscando detalhes do filme 57/574 - ID: 27098
# 🔄 Buscando detalhes do filme 58/574 - ID: 25237
# 🔄 Buscando detalhes do filme 59/574 - ID: 9361
# 🔄 Buscando detalhes do filme 60/574 - ID: 613
# 🔄 Buscando detalhes do filme 61/574 - ID: 1370
# 🔄 Buscando detalhes do filme 62/574 - ID: 429351
# 🔄 Buscando detalhes do filme 63/574 - ID: 935
# 🔄 Buscando detalhes do filme 64/574 - ID: 4476
# 🔄 Buscando detalhes do filme 65/574 - ID: 947
# 🔄 Buscando detalhes do filme 66/574 - ID: 407375
# 🔄 Buscando detalhes do filme 67/574 - ID: 919207
# 🔄 Buscando detalhes do filme 68/574 - ID: 1061699
# 🔄 Buscando detalhes do filme 69/574 - ID: 149870
# 🔄 Buscando detalhes do filme 70/574 - ID: 715931
# 🔄 Buscando detalhes do filme 71/574 - ID: 11778
# 🔄 Buscando detalhes do filme 72/574 - ID: 193756
# 🔄 Buscando detalhes do filme 73/574 - ID: 405775
# 🔄 Buscando detalhes do filme 74/574 - ID: 3175
# 🔄 Buscando detalhes do filme 75/574 - ID: 948713
# 🔄 Buscando detalhes do filme 76/574 - ID: 25
# 🔄 Buscando detalhes do filme 77/574 - ID: 2042
# 🔄 Buscando detalhes do filme 78/574 - ID: 522162
# 🔄 Buscando detalhes do filme 79/574 - ID: 554600
# 🔄 Buscando detalhes do filme 80/574 - ID: 9289
# 🔄 Buscando detalhes do filme 81/574 - ID: 12162
# 🔄 Buscando detalhes do filme 82/574 - ID: 22971
# 🔄 Buscando detalhes do filme 83/574 - ID: 11948
# 🔄 Buscando detalhes do filme 84/574 - ID: 9665
# 🔄 Buscando detalhes do filme 85/574 - ID: 9595
# 🔄 Buscando detalhes do filme 86/574 - ID: 438799
# 🔄 Buscando detalhes do filme 87/574 - ID: 5902
# 🔄 Buscando detalhes do filme 88/574 - ID: 22972
# 🔄 Buscando detalhes do filme 89/574 - ID: 591538
# 🔄 Buscando detalhes do filme 90/574 - ID: 531876
# 🔄 Buscando detalhes do filme 91/574 - ID: 1880
# 🔄 Buscando detalhes do filme 92/574 - ID: 504949
# 🔄 Buscando detalhes do filme 93/574 - ID: 15384
# 🔄 Buscando detalhes do filme 94/574 - ID: 9477
# 🔄 Buscando detalhes do filme 95/574 - ID: 653851
# 🔄 Buscando detalhes do filme 96/574 - ID: 12289
# 🔄 Buscando detalhes do filme 97/574 - ID: 1076487
# 🔄 Buscando detalhes do filme 98/574 - ID: 8619
# 🔄 Buscando detalhes do filme 99/574 - ID: 660360
# 🔄 Buscando detalhes do filme 100/574 - ID: 409
# 🔄 Buscando detalhes do filme 101/574 - ID: 94047
# 🔄 Buscando detalhes do filme 102/574 - ID: 387
# 🔄 Buscando detalhes do filme 103/574 - ID: 1061181
# 🔄 Buscando detalhes do filme 104/574 - ID: 369885
# 🔄 Buscando detalhes do filme 105/574 - ID: 8007
# 🔄 Buscando detalhes do filme 106/574 - ID: 4435
# 🔄 Buscando detalhes do filme 107/574 - ID: 592279
# 🔄 Buscando detalhes do filme 108/574 - ID: 127533
# 🔄 Buscando detalhes do filme 109/574 - ID: 983044
# 🔄 Buscando detalhes do filme 110/574 - ID: 11658
# 🔄 Buscando detalhes do filme 111/574 - ID: 832964
# 🔄 Buscando detalhes do filme 112/574 - ID: 2440
# 🔄 Buscando detalhes do filme 113/574 - ID: 57212
# 🔄 Buscando detalhes do filme 114/574 - ID: 554805
# 🔄 Buscando detalhes do filme 115/574 - ID: 11046
# 🔄 Buscando detalhes do filme 116/574 - ID: 2289
# 🔄 Buscando detalhes do filme 117/574 - ID: 517093
# 🔄 Buscando detalhes do filme 118/574 - ID: 489763
# 🔄 Buscando detalhes do filme 119/574 - ID: 826
# 🔄 Buscando detalhes do filme 120/574 - ID: 436391
# 🔄 Buscando detalhes do filme 121/574 - ID: 227306
# 🔄 Buscando detalhes do filme 122/574 - ID: 5336
# 🔄 Buscando detalhes do filme 123/574 - ID: 535389
# 🔄 Buscando detalhes do filme 124/574 - ID: 51200
# 🔄 Buscando detalhes do filme 125/574 - ID: 3683
# 🔄 Buscando detalhes do filme 126/574 - ID: 8963
# 🔄 Buscando detalhes do filme 127/574 - ID: 8741
# 🔄 Buscando detalhes do filme 128/574 - ID: 659
# 🔄 Buscando detalhes do filme 129/574 - ID: 10590
# 🔄 Buscando detalhes do filme 130/574 - ID: 345009
# 🔄 Buscando detalhes do filme 131/574 - ID: 9255
# 🔄 Buscando detalhes do filme 132/574 - ID: 975
# 🔄 Buscando detalhes do filme 133/574 - ID: 907
# 🔄 Buscando detalhes do filme 134/574 - ID: 437081
# 🔄 Buscando detalhes do filme 135/574 - ID: 553837
# 🔄 Buscando detalhes do filme 136/574 - ID: 75674
# 🔄 Buscando detalhes do filme 137/574 - ID: 17360
# 🔄 Buscando detalhes do filme 138/574 - ID: 335462
# 🔄 Buscando detalhes do filme 139/574 - ID: 11953
# 🔄 Buscando detalhes do filme 140/574 - ID: 14433
# 🔄 Buscando detalhes do filme 141/574 - ID: 12246
# 🔄 Buscando detalhes do filme 142/574 - ID: 11422
# 🔄 Buscando detalhes do filme 143/574 - ID: 32087
# 🔄 Buscando detalhes do filme 144/574 - ID: 152760
# 🔄 Buscando detalhes do filme 145/574 - ID: 581577
# 🔄 Buscando detalhes do filme 146/574 - ID: 15877
# 🔄 Buscando detalhes do filme 147/574 - ID: 454227
# 🔄 Buscando detalhes do filme 148/574 - ID: 508935
# 🔄 Buscando detalhes do filme 149/574 - ID: 31442
# 🔄 Buscando detalhes do filme 150/574 - ID: 651
# 🔄 Buscando detalhes do filme 151/574 - ID: 661231
# 🔄 Buscando detalhes do filme 152/574 - ID: 779029
# 🔄 Buscando detalhes do filme 153/574 - ID: 79553
# 🔄 Buscando detalhes do filme 154/574 - ID: 10047
# 🔄 Buscando detalhes do filme 155/574 - ID: 10592
# 🔄 Buscando detalhes do filme 156/574 - ID: 736069
# 🔄 Buscando detalhes do filme 157/574 - ID: 31439
# 🔄 Buscando detalhes do filme 158/574 - ID: 11909
# 🔄 Buscando detalhes do filme 159/574 - ID: 1251
# 🔄 Buscando detalhes do filme 160/574 - ID: 378108
# 🔄 Buscando detalhes do filme 161/574 - ID: 1654
# 🔄 Buscando detalhes do filme 162/574 - ID: 961420
# 🔄 Buscando detalhes do filme 163/574 - ID: 3536
# 🔄 Buscando detalhes do filme 164/574 - ID: 76758
# 🔄 Buscando detalhes do filme 165/574 - ID: 2841
# 🔄 Buscando detalhes do filme 166/574 - ID: 1436
# 🔄 Buscando detalhes do filme 167/574 - ID: 11780
# 🔄 Buscando detalhes do filme 168/574 - ID: 62977
# 🔄 Buscando detalhes do filme 169/574 - ID: 8738
# 🔄 Buscando detalhes do filme 170/574 - ID: 282631
# 🔄 Buscando detalhes do filme 171/574 - ID: 460555
# 🔄 Buscando detalhes do filme 172/574 - ID: 10015
# 🔄 Buscando detalhes do filme 173/574 - ID: 283587
# 🔄 Buscando detalhes do filme 174/574 - ID: 13813
# 🔄 Buscando detalhes do filme 175/574 - ID: 14087
# 🔄 Buscando detalhes do filme 176/574 - ID: 205
# 🔄 Buscando detalhes do filme 177/574 - ID: 17277
# 🔄 Buscando detalhes do filme 178/574 - ID: 332270
# 🔄 Buscando detalhes do filme 179/574 - ID: 1786
# 🔄 Buscando detalhes do filme 180/574 - ID: 607844
# 🔄 Buscando detalhes do filme 181/574 - ID: 508664
# 🔄 Buscando detalhes do filme 182/574 - ID: 10911
# 🔄 Buscando detalhes do filme 183/574 - ID: 427342
# 🔄 Buscando detalhes do filme 184/574 - ID: 633515
# 🔄 Buscando detalhes do filme 185/574 - ID: 797838
# 🔄 Buscando detalhes do filme 186/574 - ID: 8290
# 🔄 Buscando detalhes do filme 187/574 - ID: 553839
# 🔄 Buscando detalhes do filme 188/574 - ID: 2604
# 🔄 Buscando detalhes do filme 189/574 - ID: 452557
# 🔄 Buscando detalhes do filme 190/574 - ID: 25318
# 🔄 Buscando detalhes do filme 191/574 - ID: 435129
# 🔄 Buscando detalhes do filme 192/574 - ID: 14968
# 🔄 Buscando detalhes do filme 193/574 - ID: 3482
# 🔄 Buscando detalhes do filme 194/574 - ID: 11902
# 🔄 Buscando detalhes do filme 195/574 - ID: 293767
# 🔄 Buscando detalhes do filme 196/574 - ID: 74513
# 🔄 Buscando detalhes do filme 197/574 - ID: 72431
# 🔄 Buscando detalhes do filme 198/574 - ID: 11463
# 🔄 Buscando detalhes do filme 199/574 - ID: 9660
# 🔄 Buscando detalhes do filme 200/574 - ID: 12100
# 🔄 Buscando detalhes do filme 201/574 - ID: 10110
# 🔄 Buscando detalhes do filme 202/574 - ID: 899524
# 🔄 Buscando detalhes do filme 203/574 - ID: 12900
# 🔄 Buscando detalhes do filme 204/574 - ID: 21345
# 🔄 Buscando detalhes do filme 205/574 - ID: 463319
# 🔄 Buscando detalhes do filme 206/574 - ID: 468224
# 🔄 Buscando detalhes do filme 207/574 - ID: 11646
# 🔄 Buscando detalhes do filme 208/574 - ID: 11202
# 🔄 Buscando detalhes do filme 209/574 - ID: 41411
# 🔄 Buscando detalhes do filme 210/574 - ID: 316152
# 🔄 Buscando detalhes do filme 211/574 - ID: 415214
# 🔄 Buscando detalhes do filme 212/574 - ID: 801
# 🔄 Buscando detalhes do filme 213/574 - ID: 333352
# 🔄 Buscando detalhes do filme 214/574 - ID: 10364
# 🔄 Buscando detalhes do filme 215/574 - ID: 16564
# 🔄 Buscando detalhes do filme 216/574 - ID: 339259
# 🔄 Buscando detalhes do filme 217/574 - ID: 15383
# 🔄 Buscando detalhes do filme 218/574 - ID: 347629
# 🔄 Buscando detalhes do filme 219/574 - ID: 18780
# 🔄 Buscando detalhes do filme 220/574 - ID: 68942
# 🔄 Buscando detalhes do filme 221/574 - ID: 567566
# 🔄 Buscando detalhes do filme 222/574 - ID: 34528
# 🔄 Buscando detalhes do filme 223/574 - ID: 491926
# 🔄 Buscando detalhes do filme 224/574 - ID: 15873
# 🔄 Buscando detalhes do filme 225/574 - ID: 1074034
# 🔄 Buscando detalhes do filme 226/574 - ID: 302828
# 🔄 Buscando detalhes do filme 227/574 - ID: 351339
# 🔄 Buscando detalhes do filme 228/574 - ID: 10652
# 🔄 Buscando detalhes do filme 229/574 - ID: 472454
# 🔄 Buscando detalhes do filme 230/574 - ID: 498448
# 🔄 Buscando detalhes do filme 231/574 - ID: 10142
# 🔄 Buscando detalhes do filme 232/574 - ID: 10839
# 🔄 Buscando detalhes do filme 233/574 - ID: 38360
# 🔄 Buscando detalhes do filme 234/574 - ID: 252178
# 🔄 Buscando detalhes do filme 235/574 - ID: 403300
# 🔄 Buscando detalhes do filme 236/574 - ID: 11426
# 🔄 Buscando detalhes do filme 237/574 - ID: 9075
# 🔄 Buscando detalhes do filme 238/574 - ID: 26648
# 🔄 Buscando detalhes do filme 239/574 - ID: 316042
# 🔄 Buscando detalhes do filme 240/574 - ID: 9664
# 🔄 Buscando detalhes do filme 241/574 - ID: 13935
# 🔄 Buscando detalhes do filme 242/574 - ID: 289222
# 🔄 Buscando detalhes do filme 243/574 - ID: 21175
# 🔄 Buscando detalhes do filme 244/574 - ID: 505954
# 🔄 Buscando detalhes do filme 245/574 - ID: 33319
# 🔄 Buscando detalhes do filme 246/574 - ID: 10684
# 🔄 Buscando detalhes do filme 247/574 - ID: 438259
# 🔄 Buscando detalhes do filme 248/574 - ID: 573531
# 🔄 Buscando detalhes do filme 249/574 - ID: 271674
# 🔄 Buscando detalhes do filme 250/574 - ID: 433502
# 🔄 Buscando detalhes do filme 251/574 - ID: 377447
# 🔄 Buscando detalhes do filme 252/574 - ID: 8665
# 🔄 Buscando detalhes do filme 253/574 - ID: 10178
# 🔄 Buscando detalhes do filme 254/574 - ID: 20941
# 🔄 Buscando detalhes do filme 255/574 - ID: 50618
# 🔄 Buscando detalhes do filme 256/574 - ID: 618219
# 🔄 Buscando detalhes do filme 257/574 - ID: 581859
# 🔄 Buscando detalhes do filme 258/574 - ID: 6415
# 🔄 Buscando detalhes do filme 259/574 - ID: 625
# 🔄 Buscando detalhes do filme 260/574 - ID: 440626
# 🔄 Buscando detalhes do filme 261/574 - ID: 489245
# 🔄 Buscando detalhes do filme 262/574 - ID: 433694
# 🔄 Buscando detalhes do filme 263/574 - ID: 43258
# 🔄 Buscando detalhes do filme 264/574 - ID: 334517
# 🔄 Buscando detalhes do filme 265/574 - ID: 728118
# 🔄 Buscando detalhes do filme 266/574 - ID: 9952
# 🔄 Buscando detalhes do filme 267/574 - ID: 338517
# 🔄 Buscando detalhes do filme 268/574 - ID: 846867
# 🔄 Buscando detalhes do filme 269/574 - ID: 475132
# 🔄 Buscando detalhes do filme 270/574 - ID: 25998
# 🔄 Buscando detalhes do filme 271/574 - ID: 16638
# 🔄 Buscando detalhes do filme 272/574 - ID: 9839
# 🔄 Buscando detalhes do filme 273/574 - ID: 62630
# 🔄 Buscando detalhes do filme 274/574 - ID: 10655
# 🔄 Buscando detalhes do filme 275/574 - ID: 11589
# 🔄 Buscando detalhes do filme 276/574 - ID: 13405
# 🔄 Buscando detalhes do filme 277/574 - ID: 8885
# 🔄 Buscando detalhes do filme 278/574 - ID: 8881
# 🔄 Buscando detalhes do filme 279/574 - ID: 13506
# 🔄 Buscando detalhes do filme 280/574 - ID: 10479
# 🔄 Buscando detalhes do filme 281/574 - ID: 15764
# 🔄 Buscando detalhes do filme 282/574 - ID: 944194
# 🔄 Buscando detalhes do filme 283/574 - ID: 845875
# 🔄 Buscando detalhes do filme 284/574 - ID: 528210
# 🔄 Buscando detalhes do filme 285/574 - ID: 485296
# 🔄 Buscando detalhes do filme 286/574 - ID: 424488
# 🔄 Buscando detalhes do filme 287/574 - ID: 11165
# 🔄 Buscando detalhes do filme 288/574 - ID: 31217
# 🔄 Buscando detalhes do filme 289/574 - ID: 8988
# 🔄 Buscando detalhes do filme 290/574 - ID: 306650
# 🔄 Buscando detalhes do filme 291/574 - ID: 11443
# 🔄 Buscando detalhes do filme 292/574 - ID: 31642
# 🔄 Buscando detalhes do filme 293/574 - ID: 647498
# 🔄 Buscando detalhes do filme 294/574 - ID: 378385
# 🔄 Buscando detalhes do filme 295/574 - ID: 25838
# 🔄 Buscando detalhes do filme 296/574 - ID: 31427
# 🔄 Buscando detalhes do filme 297/574 - ID: 25405
# 🔄 Buscando detalhes do filme 298/574 - ID: 475094
# 🔄 Buscando detalhes do filme 299/574 - ID: 336050
# 🔄 Buscando detalhes do filme 300/574 - ID: 162215
# 🔄 Buscando detalhes do filme 301/574 - ID: 502
# 🔄 Buscando detalhes do filme 302/574 - ID: 40739
# 🔄 Buscando detalhes do filme 303/574 - ID: 37921
# 🔄 Buscando detalhes do filme 304/574 - ID: 635744
# 🔄 Buscando detalhes do filme 305/574 - ID: 11706
# 🔄 Buscando detalhes do filme 306/574 - ID: 22311
# 🔄 Buscando detalhes do filme 307/574 - ID: 644613
# 🔄 Buscando detalhes do filme 308/574 - ID: 390054
# 🔄 Buscando detalhes do filme 309/574 - ID: 31906
# 🔄 Buscando detalhes do filme 310/574 - ID: 14097
# 🔄 Buscando detalhes do filme 311/574 - ID: 34530
# 🔄 Buscando detalhes do filme 312/574 - ID: 10687
# 🔄 Buscando detalhes do filme 313/574 - ID: 296523
# 🔄 Buscando detalhes do filme 314/574 - ID: 13524
# 🔄 Buscando detalhes do filme 315/574 - ID: 29266
# 🔄 Buscando detalhes do filme 316/574 - ID: 433247
# 🔄 Buscando detalhes do filme 317/574 - ID: 5000
# 🔄 Buscando detalhes do filme 318/574 - ID: 294992
# 🔄 Buscando detalhes do filme 319/574 - ID: 11661
# 🔄 Buscando detalhes do filme 320/574 - ID: 31169
# 🔄 Buscando detalhes do filme 321/574 - ID: 426618
# 🔄 Buscando detalhes do filme 322/574 - ID: 11372
# 🔄 Buscando detalhes do filme 323/574 - ID: 5923
# 🔄 Buscando detalhes do filme 324/574 - ID: 334522
# 🔄 Buscando detalhes do filme 325/574 - ID: 10705
# 🔄 Buscando detalhes do filme 326/574 - ID: 12651
# 🔄 Buscando detalhes do filme 327/574 - ID: 435577
# 🔄 Buscando detalhes do filme 328/574 - ID: 15267
# 🔄 Buscando detalhes do filme 329/574 - ID: 26372
# 🔄 Buscando detalhes do filme 330/574 - ID: 256917
# 🔄 Buscando detalhes do filme 331/574 - ID: 10491
# 🔄 Buscando detalhes do filme 332/574 - ID: 430424
# 🔄 Buscando detalhes do filme 333/574 - ID: 11101
# 🔄 Buscando detalhes do filme 334/574 - ID: 238628
# 🔄 Buscando detalhes do filme 335/574 - ID: 11209
# 🔄 Buscando detalhes do filme 336/574 - ID: 608195
# 🔄 Buscando detalhes do filme 337/574 - ID: 78215
# 🔄 Buscando detalhes do filme 338/574 - ID: 967874
# 🔄 Buscando detalhes do filme 339/574 - ID: 25905
# 🔄 Buscando detalhes do filme 340/574 - ID: 433356
# 🔄 Buscando detalhes do filme 341/574 - ID: 17295
# 🔄 Buscando detalhes do filme 342/574 - ID: 8880
# 🔄 Buscando detalhes do filme 343/574 - ID: 1047016
# 🔄 Buscando detalhes do filme 344/574 - ID: 93289
# 🔄 Buscando detalhes do filme 345/574 - ID: 13922
# 🔄 Buscando detalhes do filme 346/574 - ID: 26843
# 🔄 Buscando detalhes do filme 347/574 - ID: 79896
# 🔄 Buscando detalhes do filme 348/574 - ID: 650031
# 🔄 Buscando detalhes do filme 349/574 - ID: 225728
# 🔄 Buscando detalhes do filme 350/574 - ID: 1941
# 🔄 Buscando detalhes do filme 351/574 - ID: 335578
# 🔄 Buscando detalhes do filme 352/574 - ID: 9093
# 🔄 Buscando detalhes do filme 353/574 - ID: 398924
# 🔄 Buscando detalhes do filme 354/574 - ID: 9967
# 🔄 Buscando detalhes do filme 355/574 - ID: 1116
# 🔄 Buscando detalhes do filme 356/574 - ID: 1098110
# 🔄 Buscando detalhes do filme 357/574 - ID: 16072
# 🔄 Buscando detalhes do filme 358/574 - ID: 19067
# 🔄 Buscando detalhes do filme 359/574 - ID: 50183
# 🔄 Buscando detalhes do filme 360/574 - ID: 33157
# 🔄 Buscando detalhes do filme 361/574 - ID: 964426
# 🔄 Buscando detalhes do filme 362/574 - ID: 46592
# 🔄 Buscando detalhes do filme 363/574 - ID: 392142
# 🔄 Buscando detalhes do filme 364/574 - ID: 339987
# 🔄 Buscando detalhes do filme 365/574 - ID: 7862
# 🔄 Buscando detalhes do filme 366/574 - ID: 19972
# 🔄 Buscando detalhes do filme 367/574 - ID: 67
# 🔄 Buscando detalhes do filme 368/574 - ID: 22549
# 🔄 Buscando detalhes do filme 369/574 - ID: 53457
# 🔄 Buscando detalhes do filme 370/574 - ID: 8198
# 🔄 Buscando detalhes do filme 371/574 - ID: 18712
# 🔄 Buscando detalhes do filme 372/574 - ID: 17339
# 🔄 Buscando detalhes do filme 373/574 - ID: 467952
# 🔄 Buscando detalhes do filme 374/574 - ID: 279641
# 🔄 Buscando detalhes do filme 375/574 - ID: 8996
# 🔄 Buscando detalhes do filme 376/574 - ID: 6106
# 🔄 Buscando detalhes do filme 377/574 - ID: 31962
# 🔄 Buscando detalhes do filme 378/574 - ID: 19155
# 🔄 Buscando detalhes do filme 379/574 - ID: 17664
# 🔄 Buscando detalhes do filme 380/574 - ID: 127372
# 🔄 Buscando detalhes do filme 381/574 - ID: 48769
# 🔄 Buscando detalhes do filme 382/574 - ID: 19728
# 🔄 Buscando detalhes do filme 383/574 - ID: 21876
# 🔄 Buscando detalhes do filme 384/574 - ID: 442065
# 🔄 Buscando detalhes do filme 385/574 - ID: 885110
# 🔄 Buscando detalhes do filme 386/574 - ID: 24167
# 🔄 Buscando detalhes do filme 387/574 - ID: 96399
# 🔄 Buscando detalhes do filme 388/574 - ID: 253239
# 🔄 Buscando detalhes do filme 389/574 - ID: 107170
# 🔄 Buscando detalhes do filme 390/574 - ID: 8266
# 🔄 Buscando detalhes do filme 391/574 - ID: 4708
# 🔄 Buscando detalhes do filme 392/574 - ID: 427008
# 🔄 Buscando detalhes do filme 393/574 - ID: 910365
# 🔄 Buscando detalhes do filme 394/574 - ID: 613093
# 🔄 Buscando detalhes do filme 395/574 - ID: 27759
# 🔄 Buscando detalhes do filme 396/574 - ID: 432616
# 🔄 Buscando detalhes do filme 397/574 - ID: 260063
# 🔄 Buscando detalhes do filme 398/574 - ID: 11296
# 🔄 Buscando detalhes do filme 399/574 - ID: 587092
# 🔄 Buscando detalhes do filme 400/574 - ID: 29572
# 🔄 Buscando detalhes do filme 401/574 - ID: 477428
# 🔄 Buscando detalhes do filme 402/574 - ID: 40709
# 🔄 Buscando detalhes do filme 403/574 - ID: 9102
# 🔄 Buscando detalhes do filme 404/574 - ID: 31894
# 🔄 Buscando detalhes do filme 405/574 - ID: 8349
# 🔄 Buscando detalhes do filme 406/574 - ID: 375012
# 🔄 Buscando detalhes do filme 407/574 - ID: 13470
# 🔄 Buscando detalhes do filme 408/574 - ID: 256962
# 🔄 Buscando detalhes do filme 409/574 - ID: 11476
# 🔄 Buscando detalhes do filme 410/574 - ID: 10912
# 🔄 Buscando detalhes do filme 411/574 - ID: 22267
# 🔄 Buscando detalhes do filme 412/574 - ID: 670439
# 🔄 Buscando detalhes do filme 413/574 - ID: 517148
# 🔄 Buscando detalhes do filme 414/574 - ID: 333696
# 🔄 Buscando detalhes do filme 415/574 - ID: 49106
# 🔄 Buscando detalhes do filme 416/574 - ID: 748787
# 🔄 Buscando detalhes do filme 417/574 - ID: 632
# 🔄 Buscando detalhes do filme 418/574 - ID: 543580
# 🔄 Buscando detalhes do filme 419/574 - ID: 29710
# 🔄 Buscando detalhes do filme 420/574 - ID: 35583
# 🔄 Buscando detalhes do filme 421/574 - ID: 13752
# 🔄 Buscando detalhes do filme 422/574 - ID: 19855
# 🔄 Buscando detalhes do filme 423/574 - ID: 89584
# 🔄 Buscando detalhes do filme 424/574 - ID: 26205
# 🔄 Buscando detalhes do filme 425/574 - ID: 12412
# 🔄 Buscando detalhes do filme 426/574 - ID: 31657
# 🔄 Buscando detalhes do filme 427/574 - ID: 497916
# 🔄 Buscando detalhes do filme 428/574 - ID: 1770
# 🔄 Buscando detalhes do filme 429/574 - ID: 554022
# 🔄 Buscando detalhes do filme 430/574 - ID: 695089
# 🔄 Buscando detalhes do filme 431/574 - ID: 16850
# 🔄 Buscando detalhes do filme 432/574 - ID: 13614
# 🔄 Buscando detalhes do filme 433/574 - ID: 293982
# 🔄 Buscando detalhes do filme 434/574 - ID: 62547
# 🔄 Buscando detalhes do filme 435/574 - ID: 484638
# 🔄 Buscando detalhes do filme 436/574 - ID: 12660
# 🔄 Buscando detalhes do filme 437/574 - ID: 14911
# 🔄 Buscando detalhes do filme 438/574 - ID: 9104
# 🔄 Buscando detalhes do filme 439/574 - ID: 284689
# 🔄 Buscando detalhes do filme 440/574 - ID: 16328
# 🔄 Buscando detalhes do filme 441/574 - ID: 618326
# 🔄 Buscando detalhes do filme 442/574 - ID: 30432
# 🔄 Buscando detalhes do filme 443/574 - ID: 28368
# 🔄 Buscando detalhes do filme 444/574 - ID: 27461
# 🔄 Buscando detalhes do filme 445/574 - ID: 405965
# 🔄 Buscando detalhes do filme 446/574 - ID: 43100
# 🔄 Buscando detalhes do filme 447/574 - ID: 17352
# 🔄 Buscando detalhes do filme 448/574 - ID: 413770
# 🔄 Buscando detalhes do filme 449/574 - ID: 29715
# 🔄 Buscando detalhes do filme 450/574 - ID: 5937
# 🔄 Buscando detalhes do filme 451/574 - ID: 239103
# 🔄 Buscando detalhes do filme 452/574 - ID: 965571
# 🔄 Buscando detalhes do filme 453/574 - ID: 13210
# 🔄 Buscando detalhes do filme 454/574 - ID: 340101
# 🔄 Buscando detalhes do filme 455/574 - ID: 321751
# 🔄 Buscando detalhes do filme 456/574 - ID: 17771
# 🔄 Buscando detalhes do filme 457/574 - ID: 32084
# 🔄 Buscando detalhes do filme 458/574 - ID: 285423
# 🔄 Buscando detalhes do filme 459/574 - ID: 542921
# 🔄 Buscando detalhes do filme 460/574 - ID: 468362
# 🔄 Buscando detalhes do filme 461/574 - ID: 664423
# 🔄 Buscando detalhes do filme 462/574 - ID: 37853
# 🔄 Buscando detalhes do filme 463/574 - ID: 23928
# 🔄 Buscando detalhes do filme 464/574 - ID: 42700
# 🔄 Buscando detalhes do filme 465/574 - ID: 12698
# 🔄 Buscando detalhes do filme 466/574 - ID: 472553
# 🔄 Buscando detalhes do filme 467/574 - ID: 283708
# 🔄 Buscando detalhes do filme 468/574 - ID: 265228
# 🔄 Buscando detalhes do filme 469/574 - ID: 10857
# 🔄 Buscando detalhes do filme 470/574 - ID: 31918
# 🔄 Buscando detalhes do filme 471/574 - ID: 22998
# 🔄 Buscando detalhes do filme 472/574 - ID: 986
# 🔄 Buscando detalhes do filme 473/574 - ID: 400728
# 🔄 Buscando detalhes do filme 474/574 - ID: 406449
# 🔄 Buscando detalhes do filme 475/574 - ID: 348674
# 🔄 Buscando detalhes do filme 476/574 - ID: 633
# 🔄 Buscando detalhes do filme 477/574 - ID: 39312
# 🔄 Buscando detalhes do filme 478/574 - ID: 8342
# 🔄 Buscando detalhes do filme 479/574 - ID: 18784
# 🔄 Buscando detalhes do filme 480/574 - ID: 788045
# 🔄 Buscando detalhes do filme 481/574 - ID: 13180
# 🔄 Buscando detalhes do filme 482/574 - ID: 10105
# 🔄 Buscando detalhes do filme 483/574 - ID: 21027
# 🔄 Buscando detalhes do filme 484/574 - ID: 1058616
# 🔄 Buscando detalhes do filme 485/574 - ID: 1566
# 🔄 Buscando detalhes do filme 486/574 - ID: 121642
# 🔄 Buscando detalhes do filme 487/574 - ID: 332179
# 🔄 Buscando detalhes do filme 488/574 - ID: 396616
# 🔄 Buscando detalhes do filme 489/574 - ID: 20850
# 🔄 Buscando detalhes do filme 490/574 - ID: 789
# 🔄 Buscando detalhes do filme 491/574 - ID: 31174
# 🔄 Buscando detalhes do filme 492/574 - ID: 1863
# 🔄 Buscando detalhes do filme 493/574 - ID: 10368
# 🔄 Buscando detalhes do filme 494/574 - ID: 8056
# 🔄 Buscando detalhes do filme 495/574 - ID: 403357
# 🔄 Buscando detalhes do filme 496/574 - ID: 15876
# 🔄 Buscando detalhes do filme 497/574 - ID: 401306
# 🔄 Buscando detalhes do filme 498/574 - ID: 38251
# 🔄 Buscando detalhes do filme 499/574 - ID: 15192
# 🔄 Buscando detalhes do filme 500/574 - ID: 19382
# 🔄 Buscando detalhes do filme 501/574 - ID: 128158
# 🔄 Buscando detalhes do filme 502/574 - ID: 67297
# 🔄 Buscando detalhes do filme 503/574 - ID: 1783
# 🔄 Buscando detalhes do filme 504/574 - ID: 1716
# 🔄 Buscando detalhes do filme 505/574 - ID: 29933
# 🔄 Buscando detalhes do filme 506/574 - ID: 437031
# 🔄 Buscando detalhes do filme 507/574 - ID: 321303
# 🔄 Buscando detalhes do filme 508/574 - ID: 32041
# 🔄 Buscando detalhes do filme 509/574 - ID: 37129
# 🔄 Buscando detalhes do filme 510/574 - ID: 24395
# 🔄 Buscando detalhes do filme 511/574 - ID: 8883
# 🔄 Buscando detalhes do filme 512/574 - ID: 1018332
# 🔄 Buscando detalhes do filme 513/574 - ID: 13783
# 🔄 Buscando detalhes do filme 514/574 - ID: 403450
# 🔄 Buscando detalhes do filme 515/574 - ID: 32054
# 🔄 Buscando detalhes do filme 516/574 - ID: 20848
# 🔄 Buscando detalhes do filme 517/574 - ID: 2016
# 🔄 Buscando detalhes do filme 518/574 - ID: 263855
# 🔄 Buscando detalhes do filme 519/574 - ID: 75525
# 🔄 Buscando detalhes do filme 520/574 - ID: 14582
# 🔄 Buscando detalhes do filme 521/574 - ID: 36583
# 🔄 Buscando detalhes do filme 522/574 - ID: 73686
# 🔄 Buscando detalhes do filme 523/574 - ID: 5055
# 🔄 Buscando detalhes do filme 524/574 - ID: 61231
# 🔄 Buscando detalhes do filme 525/574 - ID: 11316
# 🔄 Buscando detalhes do filme 526/574 - ID: 12503
# 🔄 Buscando detalhes do filme 527/574 - ID: 43195
# 🔄 Buscando detalhes do filme 528/574 - ID: 13560
# 🔄 Buscando detalhes do filme 529/574 - ID: 37103
# 🔄 Buscando detalhes do filme 530/574 - ID: 38884
# 🔄 Buscando detalhes do filme 531/574 - ID: 55823
# 🔄 Buscando detalhes do filme 532/574 - ID: 48580
# 🔄 Buscando detalhes do filme 533/574 - ID: 55368
# 🔄 Buscando detalhes do filme 534/574 - ID: 42130
# 🔄 Buscando detalhes do filme 535/574 - ID: 23908
# 🔄 Buscando detalhes do filme 536/574 - ID: 24559
# 🔄 Buscando detalhes do filme 537/574 - ID: 42617
# 🔄 Buscando detalhes do filme 538/574 - ID: 58736
# 🔄 Buscando detalhes do filme 539/574 - ID: 39787
# 🔄 Buscando detalhes do filme 540/574 - ID: 14111
# 🔄 Buscando detalhes do filme 541/574 - ID: 121835
# 🔄 Buscando detalhes do filme 542/574 - ID: 416211
# 🔄 Buscando detalhes do filme 543/574 - ID: 14905
# 🔄 Buscando detalhes do filme 544/574 - ID: 43418
# 🔄 Buscando detalhes do filme 545/574 - ID: 263614
# 🔄 Buscando detalhes do filme 546/574 - ID: 31681
# 🔄 Buscando detalhes do filme 547/574 - ID: 16121
# 🔄 Buscando detalhes do filme 548/574 - ID: 48955
# 🔄 Buscando detalhes do filme 549/574 - ID: 427347
# 🔄 Buscando detalhes do filme 550/574 - ID: 98205
# 🔄 Buscando detalhes do filme 551/574 - ID: 519187
# 🔄 Buscando detalhes do filme 552/574 - ID: 37828
# 🔄 Buscando detalhes do filme 553/574 - ID: 47904
# 🔄 Buscando detalhes do filme 554/574 - ID: 37550
# 🔄 Buscando detalhes do filme 555/574 - ID: 576017
# 🔄 Buscando detalhes do filme 556/574 - ID: 127918
# 🔄 Buscando detalhes do filme 557/574 - ID: 26508
# 🔄 Buscando detalhes do filme 558/574 - ID: 34671
# 🔄 Buscando detalhes do filme 559/574 - ID: 463800
# 🔄 Buscando detalhes do filme 560/574 - ID: 84288
# 🔄 Buscando detalhes do filme 561/574 - ID: 474944
# 🔄 Buscando detalhes do filme 562/574 - ID: 29270
# 🔄 Buscando detalhes do filme 563/574 - ID: 500915
# 🔄 Buscando detalhes do filme 564/574 - ID: 78101
# 🔄 Buscando detalhes do filme 565/574 - ID: 246871
# 🔄 Buscando detalhes do filme 566/574 - ID: 33336
# 🔄 Buscando detalhes do filme 567/574 - ID: 947962
# 🔄 Buscando detalhes do filme 568/574 - ID: 822010
# 🔄 Buscando detalhes do filme 569/574 - ID: 53200
# 🔄 Buscando detalhes do filme 570/574 - ID: 27957
# 🔄 Buscando detalhes do filme 571/574 - ID: 27357
# 🔄 Buscando detalhes do filme 572/574 - ID: 203793
# 🔄 Buscando detalhes do filme 573/574 - ID: 184374
# 🔄 Buscando detalhes do filme 574/574 - ID: 12477
# ✅ Arquivo salvo como 'filmes_guerra_detalhes.csv'

# %% [markdown]
# - Carregando o CSV completo com os dados detalhados dos filmes, observando o nome, tipo da coluna e as primeiras linhas

# %%
df = pd.read_csv("filmes_guerra_detalhes.csv")

print(df.dtypes)

df.head(3)
# Out:
# adult                                     bool
# backdrop_path                           object
# belongs_to_collection                  float64
# budget                                   int64
# genres                                  object
# homepage                                object
# id                                       int64
# imdb_id                                 object
# origin_country                          object
# original_language                       object
# original_title                          object
# overview                                object
# popularity                             float64
# poster_path                             object
# production_companies                    object
# production_countries                    object
# release_date                            object
# revenue                                  int64
# runtime                                  int64
# spoken_languages                        object
# status                                  object
# tagline                                 object
# title                                   object
# video                                     bool
# vote_average                           float64
# vote_count                               int64
# credits.cast                            object
# credits.crew                            object
# keywords.keywords                       object
# release_dates.results                   object
# belongs_to_collection.id               float64
# belongs_to_collection.name              object
# belongs_to_collection.poster_path       object
# belongs_to_collection.backdrop_path     object
# dtype: object
#    adult                     backdrop_path  belongs_to_collection     budget  \
# 0  False  /cJvUJEEQ86LSjl4gFLkYpdCJC96.jpg                    NaN   20000000
# 1  False  /ulMscezy9YX0bhknvJbZoUgQxO5.jpg                    NaN  150000000
# 2  False  /lTyikzfGgRX5ZqIfVeT26APYfRL.jpg                    NaN   14000000
#
#                                               genres  \
# 0  [{'id': 10752, 'name': 'Guerra'}, {'id': 28, '...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 2  [{'id': 35, 'name': 'Comédia'}, {'id': 10752, ...
#
#                                             homepage       id     imdb_id  \
# 0  https://www.primevideo.com/detail/0HNFQXGDR0N8...  1241436  tt31434639
# 1                                                NaN   281338   tt3450958
# 2           http://www.foxsearchlight.com/jojorabbit   515001   tt2584384
#
#   origin_country original_language  ... vote_average vote_count  \
# 0         ['US']                en  ...        7.291        522
# 1         ['US']                en  ...        7.207       9269
# 2         ['US']                en  ...        8.005       9826
#
#                                         credits.cast  \
# 0  [{'adult': False, 'gender': 2, 'id': 2710333, ...
# 1  [{'adult': False, 'gender': 2, 'id': 1333, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 2054851, ...
#
#                                         credits.crew  \
# 0  [{'adult': False, 'gender': 2, 'id': 2036, 'kn...
# 1  [{'adult': False, 'gender': 1, 'id': 1275224, ...
# 2  [{'adult': False, 'gender': 0, 'id': 584902, '...
#
#                                    keywords.keywords  \
# 0  [{'id': 11219, 'name': 'u.s. navy seal'}, {'id...
# 1  [{'id': 236, 'name': 'suicide'}, {'id': 393, '...
# 2  [{'id': 818, 'name': 'based on novel or book'}...
#
#                                release_dates.results belongs_to_collection.id  \
# 0  [{'iso_3166_1': 'AS', 'release_dates': [{'cert...                      NaN
# 1  [{'iso_3166_1': 'AE', 'release_dates': [{'cert...                 173710.0
# 2  [{'iso_3166_1': 'AU', 'release_dates': [{'cert...                      NaN
#
#               belongs_to_collection.name  belongs_to_collection.poster_path  \
# 0                                    NaN                                NaN
# 1  Planeta dos Macacos (Reboot): Coleção   /g4RGKFHOKCWrPXncwHdmzMv1RdU.jpg
# 2                                    NaN                                NaN
#
#   belongs_to_collection.backdrop_path
# 0                                 NaN
# 1    /iMhm0g555HgQNIXAMvnlgOiW5Rz.jpg
# 2                                 NaN
#
# [3 rows x 34 columns]

# %% [markdown]
# - Quais colunas têm muitos valores faltantes

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# belongs_to_collection                  574
# homepage                               562
# belongs_to_collection.backdrop_path    515
# belongs_to_collection.poster_path      507
# belongs_to_collection.name             503
# belongs_to_collection.id               503
# tagline                                324
# overview                                33
# vote_count                               0
# title                                    0
# video                                    0
# vote_average                             0
# credits.crew                             0
# credits.cast                             0
# spoken_languages                         0
# keywords.keywords                        0
# release_dates.results                    0
# status                                   0
# adult                                    0
# runtime                                  0
# dtype: int64

# %% [markdown]
# - Exemplo do elenco de um dos filmes

# %%
import ast
exemplo_cast = ast.literal_eval(df.loc[0, "credits.cast"])
exemplo_cast[:3]
# Out:
# [{'adult': False,
#   'gender': 2,
#   'id': 2710333,
#   'known_for_department': 'Acting',
#   'name': "D'Pharaoh Woon-A-Tai",
#   'original_name': "D'Pharaoh Woon-A-Tai",
#   'popularity': 0.8848,
#   'profile_path': '/ozEGeNK9r2EFn4rNU0DSuNQaia0.jpg',
#   'cast_id': 14,
#   'character': 'Ray',
#   'credit_id': '65dff11c880c920186270dcb',
#   'order': 0},
#  {'adult': False,
#   'gender': 2,
#   'id': 93491,
#   'known_for_department': 'Acting',
#   'name': 'Will Poulter',
#   'original_name': 'Will Poulter',
#   'popularity': 4.3004,
#   'profile_path': '/9blYMaj79VGC6BHTLmJp3V5S8r3.jpg',
#   'cast_id': 17,
#   'character': 'Erik',
#   'credit_id': '660595f2ecaef50161afb31e',
#   'order': 1},
#  {'adult': False,
#   'gender': 2,
#   'id': 1363054,
#   'known_for_department': 'Acting',
#   'name': 'Cosmo Jarvis',
#   'original_name': 'Cosmo Jarvis',
#   'popularity': 3.2687,
#   'profile_path': '/1kgghZ558CxZCJip5ufO6BAqUGp.jpg',
#   'cast_id': 16,
#   'character': 'Elliott',
#   'credit_id': '660595ececaef5017ab055e5',
#   'order': 2}]

# %% [markdown]
# - Países presentes

# %%
exemplo_paises = ast.literal_eval(df.loc[0, "production_countries"])
exemplo_paises
# Out:
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#  {'iso_3166_1': 'US', 'name': 'United States of America'}]

# %% [markdown]
# Verificando como estão os dados de elenco

# %%
import ast


elenco_exemplo = df.loc[0, "credits.cast"]
elenco_df = pd.DataFrame(elenco_exemplo)
elenco_df[["name", "character", "gender", "order"]].head(10)
# Out:
#                    name      character  gender  order
# 0  D'Pharaoh Woon-A-Tai            Ray       2      0
# 1          Will Poulter           Erik       2      1
# 2          Cosmo Jarvis        Elliott       2      2
# 3            Kit Connor          Tommy       2      3
# 4          Finn Bennett           John       2      4
# 5     Taylor John Smith          Frank       2      5
# 6    Michael Gandolfini  Lt. MacDonald       2      6
# 7         Adain Bradley    Sgt Laerrus       2      7
# 8         Noah Centineo          Brian       2      8
# 9         Evan Holtzman          Brock       2      9

# %% [markdown]
#  Verificando os diretores dos filmes

# %%
df = pd.read_csv("filmes_guerra_detalhes.csv")

def extrair_diretores(crew_str):
    try:
        crew = ast.literal_eval(crew_str)  
    except:
        return []
    diretores = [p['name'] for p in crew if p.get('job') == 'Director']
    return diretores

df['diretores'] = df['credits.crew'].apply(extrair_diretores)

diretores_visao = df[['title', 'release_date', 'diretores']].head(10)
print(diretores_visao)

diretores_visao
# Out:
#                            title release_date                    diretores
# 0                Tempo de Guerra   2025-04-09  [Ray Mendoza, Alex Garland]
# 1  Planeta dos Macacos: A Guerra   2017-07-11                [Matt Reeves]
# 2                    Jojo Rabbit   2019-10-18              [Taika Waititi]
# 3             Até o Último Homem   2016-10-07                 [Mel Gibson]
# 4                  Major Imortal   2024-10-31         [Rajkumar Periasamy]
# 5                   Dirty Angels   2024-12-11            [Martin Campbell]
# 6            Bastardos Inglórios   2009-08-02          [Quentin Tarantino]
# 7                   Guerra Civil   2024-04-10               [Alex Garland]
# 8                        Platoon   1986-12-19               [Oliver Stone]
# 9              Corações de Ferro   2014-10-15                 [David Ayer]
#                            title release_date                    diretores
# 0                Tempo de Guerra   2025-04-09  [Ray Mendoza, Alex Garland]
# 1  Planeta dos Macacos: A Guerra   2017-07-11                [Matt Reeves]
# 2                    Jojo Rabbit   2019-10-18              [Taika Waititi]
# 3             Até o Último Homem   2016-10-07                 [Mel Gibson]
# 4                  Major Imortal   2024-10-31         [Rajkumar Periasamy]
# 5                   Dirty Angels   2024-12-11            [Martin Campbell]
# 6            Bastardos Inglórios   2009-08-02          [Quentin Tarantino]
# 7                   Guerra Civil   2024-04-10               [Alex Garland]
# 8                        Platoon   1986-12-19               [Oliver Stone]
# 9              Corações de Ferro   2014-10-15                 [David Ayer]

# %% [markdown]
# verificando as diretoras de filmes

# %%
df = pd.read_csv("filmes_guerra_detalhes.csv")

def extrair_diretoras(crew_str):
    try:
        crew = ast.literal_eval(crew_str)
    except:
        return []
    diretoras = [p['name'] for p in crew if p.get('job') == 'Director' and p.get('gender') == 1]
    return diretoras

df['diretoras'] = df['credits.crew'].apply(extrair_diretoras)

df_diretoras = df[df['diretoras'].apply(lambda x: len(x) > 0)]

df_diretoras[['title', 'release_date', 'diretoras']].head(10)
# Out:
#                        title release_date          diretoras
# 80          Guerra ao Terror   2008-10-10  [Kathryn Bigelow]
# 110                      Lee   2024-09-12      [Ellen Kuras]
# 120               Invencível   2014-12-25   [Angelina Jolie]
# 190              A Ganha-Pão   2017-11-17      [Nora Twomey]
# 208              Amor e Ódio   2010-03-10   [Roselyne Bosch]
# 237      O Porteiro da Noite   1974-04-03   [Liliana Cavani]
# 241  O Zoológico de Varsóvia   2017-03-24        [Niki Caro]
# 247             Halo: Lendas   2010-02-16              [清水恵]
# 251                      K19   2002-07-19  [Kathryn Bigelow]
# 264         Quo Vadis, Aida?   2021-02-26   [Jasmila Žbanić]

# %% [markdown]
# Personagem femininas em destaque

# %%
df = pd.read_csv("filmes_guerra_detalhes.csv")

def extrair_personagens_femininas(cast_str):
    try:
        cast_list = ast.literal_eval(cast_str)
        mulheres_principais = [
            {
                'name': pessoa.get('name'),
                'character': pessoa.get('character'),
                'order': pessoa.get('order')
            }
            for pessoa in cast_list
            if pessoa.get('gender') == 1 and pessoa.get('order') is not None and pessoa.get('order') < 5
        ]
        return mulheres_principais
    except:
        return []

df['personagens_femininas_destaque'] = df['credits.cast'].apply(extrair_personagens_femininas)

df_filtrado = df[df['personagens_femininas_destaque'].apply(len) > 0][['title', 'release_date', 'personagens_femininas_destaque']]
df_filtrado.head(10)
# Out:
#                             title release_date  \
# 1   Planeta dos Macacos: A Guerra   2017-07-11
# 2                     Jojo Rabbit   2019-10-18
# 3              Até o Último Homem   2016-10-07
# 4                   Major Imortal   2024-10-31
# 5                    Dirty Angels   2024-12-11
# 6             Bastardos Inglórios   2009-08-02
# 7                    Guerra Civil   2024-04-10
# 10           A Lista de Schindler   1993-12-15
# 13                        Cruzada   2005-05-03
# 14                       Napoleão   2023-11-22
#
#                        personagens_femininas_destaque
# 1   [{'name': 'Karin Konoval', 'character': 'Mauri...
# 2   [{'name': 'Thomasin McKenzie', 'character': 'E...
# 3   [{'name': 'Teresa Palmer', 'character': 'Dorot...
# 4   [{'name': 'Sai Pallavi', 'character': 'Indhu R...
# 5   [{'name': 'Eva Green', 'character': 'Jake', 'o...
# 6   [{'name': 'Mélanie Laurent', 'character': 'Sho...
# 7   [{'name': 'Kirsten Dunst', 'character': 'Lee',...
# 10  [{'name': 'Caroline Goodall', 'character': 'Em...
# 13  [{'name': 'Eva Green', 'character': 'Sibylla',...
# 14  [{'name': 'Vanessa Kirby', 'character': 'Josep...
