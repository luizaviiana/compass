# %%
import pandas as pd

# CSV original com elenco
df_csv = pd.read_csv("movies.csv", sep='|', na_values='\\N')

# JSON convertido para CSV da API TMDB
df_tmdb = pd.read_csv("filmes_guerra_detalhes.csv")

# %%
# Exemplo de IDs únicos em cada base
print("IDs no CSV:", df_csv['id'].nunique())
print("IMDb IDs no TMDB:", df_tmdb['imdb_id'].nunique())

# Verificar interseção
ids_csv = set(df_csv['id'].dropna().unique())
ids_tmdb = set(df_tmdb['imdb_id'].dropna().unique())
ids_comuns = ids_csv.intersection(ids_tmdb)

print(f"IDs em comum entre CSV e TMDB: {len(ids_comuns)}")
# Out:
# IDs no CSV: 244543
# IMDb IDs no TMDB: 574
# IDs em comum entre CSV e TMDB: 511

# %%
# Set com os IMDb IDs que estão no TMDB, mas não no CSV
ids_tmdb_nao_estao_csv = ids_tmdb.difference(ids_csv)

print(f"Total de filmes TMDB que não estão no CSV: {len(ids_tmdb_nao_estao_csv)}")

# Ver os títulos desses filmes
df_tmdb_nao_casados = df_tmdb[df_tmdb['imdb_id'].isin(ids_tmdb_nao_estao_csv)][['imdb_id', 'title', 'release_date']]
print(df_tmdb_nao_casados.head(10))
# Out:
# Total de filmes TMDB que não estão no CSV: 63
#        imdb_id              title release_date
# 0   tt31434639    Tempo de Guerra   2025-04-09
# 1   tt27118357      Major Imortal   2024-10-31
# 3   tt23872640       Dirty Angels   2024-12-11
# 6   tt17279496       Guerra Civil   2024-04-10
# 8   tt19864802      Zona de Risco   2024-02-09
# 12   tt5177120  Guerra Sem Regras   2024-04-18
# 15  tt13287846           Napoleão   2023-11-22
# 16   tt4873118            O Pacto   2023-04-19
# 32   tt7160372  Zona de Interesse   2023-12-15
# 39  tt23782584          Número 24   2024-10-30

# %%
# Conjunto de imdb_ids do TMDB que não estão no CSV
ids_tmdb_nao_estao_csv = ids_tmdb.difference(ids_csv)

# Filtrar no dataframe do TMDB
df_tmdb_nao_casados = df_tmdb[df_tmdb['imdb_id'].isin(ids_tmdb_nao_estao_csv)][['imdb_id', 'title', 'release_date']]

# Exibir todos os filmes não casados
pd.set_option('display.max_rows', None)  # Mostra todas as linhas
print(df_tmdb_nao_casados.sort_values(by='release_date'))
# Out:
#         imdb_id                                        title release_date
# 544   tt0059894                             O Jogo da Guerra   1966-04-13
# 319   tt0078753                            Adeus à Inocência   1979-11-14
# 136   tt0090163                           Catástrofe Nuclear   1984-09-23
# 216   tt0092978                              Fuga de Sobibor   1987-04-12
# 218   tt0114745                                Prova de Fogo   1995-08-25
# 366   tt0135706                    Quando os Bravos se Calam   1998-06-27
# 347   tt0266425                                  Conspiração   2001-05-19
# 497   tt0287535                            O Último Batalhão   2001-12-02
# 504   tt0317910                        Sob a Névoa da Guerra   2003-10-26
# 566   tt0440846                                   Fallen Art   2004-09-23
# 413   tt0821638         Enterrem Meu Coração na Curva do Rio   2007-05-27
# 420   tt1192431                               Мы из будущего   2008-02-21
# 272   tt1185616                             Valsa com Bashir   2008-06-12
# 485   tt1332128                           Zeitgeist Addendum   2008-10-02
# 362   tt1010278                             Filhos da Guerra   2009-04-19
# 178   tt1019454                        O Retorno de Um Herói   2009-09-21
# 238   tt1480660                                 Halo: Lendas   2010-02-16
# 552   tt1640680                                    Armadillo   2010-05-27
# 476   tt1559549                                     Restrepo   2010-06-25
# 568   tt2120152                           A Guerra Invisível   2012-01-20
# 481   tt2386231                           Ghost Recon: Alpha   2012-05-03
# 507   tt2309788                                 Os Guardiões   2012-07-09
# 438   tt2992552   Atrás das Linhas Inimigas 4: Missão África   2014-05-23
# 357   tt3699508            Soldado Anônimo - Campo Em Chamas   2014-08-14
# 477   tt3455224                                      VIRUNGA   2014-11-07
# 505   tt3822818                               Nu Entre Lobos   2015-04-01
# 245   tt1365050                          Beasts of No Nation   2015-09-11
# 265   tt4616014                  Soldado Anônimo 3 - O Cerco   2016-01-20
# 95    tt5090828                         O Atirador: Fantasma   2016-08-02
# 538   tt6073176                         Os Capacetes Brancos   2016-09-16
# 561   tt7078926                                     Firebase   2017-06-28
# 465   tt7905466                        Eles Não Envelhecerão   2018-11-09
# 523   tt9617456                                    Para Sama   2019-07-26
# 177  tt10767720              Soldado Anônimo: Lei do Retorno   2019-10-01
# 562  tt13475382                                    Danny Boy   2021-05-12
# 62   tt12530246      Emancipation: Uma História de Liberdade   2022-12-02
# 339  tt18092672                              Corrida do Ouro   2022-12-15
# 240   tt8270664                                   À Espreita   2023-02-24
# 59   tt15767808       The Last Kingdom: Seven Kings Must Die   2023-04-14
# 16    tt4873118                                      O Pacto   2023-04-19
# 128  tt18073328                                Sangue e Ouro   2023-04-21
# 71   tt16527824                      Seals: Operação Resgate   2023-06-30
# 453  tt24082438                          20 Dias em Mariupol   2023-07-14
# 43    tt6979756  Criação dos Deuses I: Reino das Tempestades   2023-07-15
# 167  tt25406052                Kingdom 3: A Chama do Destino   2023-07-28
# 370  tt14454876                Golda - A Mulher de uma Nação   2023-08-23
# 459  tt24249946           A Corte Marcial Da Nave Da Revolta   2023-09-03
# 480  tt14124080                                A Grande Fuga   2023-10-06
# 508  tt23573936                                   Comandante   2023-10-31
# 15   tt13287846                                     Napoleão   2023-11-22
# 94   tt22507524                                 12.12: O Dia   2023-11-22
# 32    tt7160372                            Zona de Interesse   2023-12-15
# 110  tt22813112                          Noryang: Deadly Sea   2023-12-20
# 166  tt27724113                            The Arctic Convoy   2023-12-25
# 8    tt19864802                                Zona de Risco   2024-02-09
# 6    tt17279496                                 Guerra Civil   2024-04-10
# 12    tt5177120                            Guerra Sem Regras   2024-04-18
# 55    tt5112584                                          Lee   2024-09-12
# 39   tt23782584                                    Número 24   2024-10-30
# 1    tt27118357                                Major Imortal   2024-10-31
# 82   tt24458622                                Batalhão 6888   2024-12-06
# 3    tt23872640                                 Dirty Angels   2024-12-11
# 0    tt31434639                              Tempo de Guerra   2025-04-09

# %%
# 1️⃣ Parte comum (interseção)
df_csv_tmdb = df_csv[
    (df_csv['id'].isin(ids_comuns)) &
    (df_csv['anoLancamento'] >= 1950) &
    (df_csv['notaMedia'] >= 6) &
    (df_csv['numeroVotos'] >= 100)
]

df_tmdb_comuns = df_tmdb[df_tmdb['imdb_id'].isin(ids_comuns)]

df_merged_comuns = df_csv_tmdb.merge(
    df_tmdb_comuns,
    how='left',
    left_on='id',
    right_on='imdb_id',
    suffixes=('_csv', '_tmdb')
)

# 2️⃣ Parte exclusiva do CSV (filmes válidos, mas não estão no TMDB)
ids_exclusivos_csv = ids_csv.difference(ids_tmdb)

df_csv_exclusivo = df_csv[
    (df_csv['id'].isin(ids_exclusivos_csv)) &
    (df_csv['anoLancamento'] >= 1950) &
    (df_csv['notaMedia'] >= 6) &
    (df_csv['numeroVotos'] >= 100)
]

# 3️⃣ Parte exclusiva do TMDB (filmes válidos, mas não estão no CSV)
ids_exclusivos_tmdb = ids_tmdb.difference(ids_csv)

df_tmdb_exclusivo = df_tmdb[
    (df_tmdb['imdb_id'].isin(ids_exclusivos_tmdb)) &
    (df_tmdb['release_date'] >= '1950-01-01') &
    (df_tmdb['vote_average'] >= 6) &
    (df_tmdb['vote_count'] >= 100)
]

# %%
# ⚠️ Garanta que esses DataFrames já existem antes de rodar isso:
# - df_csv_exclusivo
# - df_tmdb_exclusivo
# - df_tmdb
# - df_csv

# 1️⃣ Forçar cópias para evitar o SettingWithCopyWarning
df_csv_exclusivo = df_csv_exclusivo.copy()
df_tmdb_exclusivo = df_tmdb_exclusivo.copy()

# 2️⃣ Adicionar colunas da TMDB no CSV exclusivo (preenchidas com pd.NA)
for col in df_tmdb.columns:
    if col not in df_csv_exclusivo.columns:
        df_csv_exclusivo.loc[:, col] = pd.NA

# 3️⃣ Adicionar colunas do CSV no TMDB exclusivo (preenchidas com pd.NA)
for col in df_csv.columns:
    if col not in df_tmdb_exclusivo.columns:
        df_tmdb_exclusivo.loc[:, col] = pd.NA

# 4️⃣ Padronizar a chave 'id' e 'imdb_id'
df_csv_exclusivo.loc[:, 'imdb_id'] = df_csv_exclusivo['id']
df_tmdb_exclusivo.loc[:, 'id'] = df_tmdb_exclusivo['imdb_id']

# %%
# 1️⃣ Criar uma flag de origem para cada parte
df_merged_comuns = df_merged_comuns.copy()
df_csv_exclusivo = df_csv_exclusivo.copy()
df_tmdb_exclusivo = df_tmdb_exclusivo.copy()

df_merged_comuns["fonte_origem"] = "csv+tmdb"
df_csv_exclusivo["fonte_origem"] = "csv"
df_tmdb_exclusivo["fonte_origem"] = "tmdb"

# 2️⃣ Garantir mesmas colunas em todas as bases
colunas_comuns = df_merged_comuns.columns.intersection(df_csv_exclusivo.columns)
colunas_comuns = colunas_comuns.intersection(df_tmdb_exclusivo.columns)

# 3️⃣ Concatenar as 3 partes em um DataFrame final
df_final = pd.concat([
    df_merged_comuns[colunas_comuns],
    df_csv_exclusivo[colunas_comuns],
    df_tmdb_exclusivo[colunas_comuns]
], ignore_index=True)
# Out:
# C:\Users\luiza\AppData\Local\Temp\ipykernel_21668\3946869102.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat([

# %%
# Quantidade total de filmes únicos
print("Total de filmes únicos:", df_final['id'].nunique())

# Contagem por origem
print(df_final['fonte_origem'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Quantidade total de filmes únicos
# ----> 2 print("Total de filmes únicos:", df_final['id'].nunique())
#       4 # Contagem por origem
#       5 print(df_final['fonte_origem'].value_counts())
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'id'

# %%
print(df_final.columns.tolist())
# Out:
# ['tituloPincipal', 'tituloOriginal', 'anoLancamento', 'tempoMinutos', 'genero', 'notaMedia', 'numeroVotos', 'generoArtista', 'personagem', 'nomeArtista', 'anoNascimento', 'anoFalecimento', 'profissao', 'titulosMaisConhecidos', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count', 'credits.cast', 'credits.crew', 'keywords.keywords', 'release_dates.results', 'belongs_to_collection.id', 'belongs_to_collection.name', 'belongs_to_collection.poster_path', 'belongs_to_collection.backdrop_path', 'fonte_origem']

# %%
# Quantidade total de filmes únicos
print("Total de filmes únicos:", df_final['imdb_id'].nunique())

# Contagem por origem
print(df_final['fonte_origem'].value_counts())
# Out:
# Total de filmes únicos: 52538
# fonte_origem
# csv         211330
# csv+tmdb      1942
# tmdb            63
# Name: count, dtype: int64

# %%
# Filtro para filmes válidos do CSV
filtro_csv = (
    (df_final['fonte_origem'].isin(['csv', 'csv+tmdb'])) &
    (df_final['anoLancamento'].notnull()) &
    (df_final['notaMedia'] >= 6) &
    (df_final['numeroVotos'] >= 100) &
    (df_final['anoLancamento'] >= 1950)
)

# Filtro para filmes válidos do TMDB (filtrados na ingestão, mas vamos reforçar)
filtro_tmdb = (
    (df_final['fonte_origem'].isin(['tmdb', 'csv+tmdb'])) &
    (df_final['vote_average'] >= 6) &
    (df_final['vote_count'] >= 100) &
    (pd.to_datetime(df_final['release_date'], errors='coerce').dt.year >= 1950)
)

# Filmes que atendem aos critérios em qualquer uma das fontes
filtro_geral = filtro_csv | filtro_tmdb

# Aplicar filtro final
df_filmes_filtrados = df_final[filtro_geral]

# Ver resultados
print("🔎 Total de registros após aplicar os filtros:", len(df_filmes_filtrados))
print("🎬 Total de filmes únicos:", df_filmes_filtrados['imdb_id'].nunique())
print("📁 Distribuição por fonte:")
print(df_filmes_filtrados['fonte_origem'].value_counts())
# Out:
# 🔎 Total de registros após aplicar os filtros: 213335
# 🎬 Total de filmes únicos: 52538
# 📁 Distribuição por fonte:
# fonte_origem
# csv         211330
# csv+tmdb      1942
# tmdb            63
# Name: count, dtype: int64

# %% [markdown]
# vou trabalhar com os filmes que tenham apenas no csv e tmdb (1942)

# %% [markdown]
# so filmes de guerra,  a base é 1911

# %%
import ast

# Função para verificar se 'guerra' está nos gêneros do TMDB
def contem_genero_guerra_tmdb(generos_str):
    try:
        generos = ast.literal_eval(generos_str)
        return any('guerra' in g['name'].lower() for g in generos)
    except:
        return False

# Filtro por gênero 'guerra' no CSV
filtro_guerra_csv = df_filmes_filtrados['genero'].str.contains('War', case=False, na=False)

# Filtro por gênero 'guerra' no TMDB
filtro_guerra_tmdb = df_filmes_filtrados['genres'].apply(contem_genero_guerra_tmdb)

# Combinar os dois filtros
filtro_guerra_total = filtro_guerra_csv | filtro_guerra_tmdb

# Aplicar o filtro
df_filmes_guerra = df_filmes_filtrados[filtro_guerra_total].copy()

# Exibir resultados
print("🎯 Total de filmes de guerra (filtrados):", df_filmes_guerra['imdb_id'].nunique())
print("📁 Distribuição por fonte:")
print(df_filmes_guerra['fonte_origem'].value_counts())
# Out:
# 🎯 Total de filmes de guerra (filtrados): 1911
# 📁 Distribuição por fonte:
# fonte_origem
# csv         5417
# csv+tmdb    1942
# tmdb          63
# Name: count, dtype: int64

# %%
df_guerra_completo = df_filmes_guerra[df_filmes_guerra['fonte_origem'] == 'csv+tmdb']
print("🎯 Total de filmes de guerra com dados CSV + TMDB:", df_guerra_completo['imdb_id'].nunique())
# Out:
# 🎯 Total de filmes de guerra com dados CSV + TMDB: 486

# %% [markdown]
# tratando dados

# %%
df_refined = df_guerra_completo.copy()

# %%
df_refined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1942 entries, 0 to 1941
# Data columns (total 48 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   tituloPincipal                       1942 non-null   object
#  1   tituloOriginal                       1942 non-null   object
#  2   anoLancamento                        1942 non-null   Int64
#  3   tempoMinutos                         1942 non-null   Int64
#  4   genero                               1942 non-null   object
#  5   notaMedia                            1942 non-null   float64
#  6   numeroVotos                          1942 non-null   Int64
#  7   generoArtista                        1942 non-null   object
#  8   personagem                           1929 non-null   object
#  9   nomeArtista                          1942 non-null   object
#  10  anoNascimento                        1758 non-null   float64
#  11  anoFalecimento                       445 non-null    float64
#  12  profissao                            1935 non-null   object
#  13  titulosMaisConhecidos                1942 non-null   object
#  14  adult                                1942 non-null   object
#  15  backdrop_path                        1942 non-null   object
#  16  belongs_to_collection                0 non-null      object
#  17  budget                               1942 non-null   object
#  18  genres                               1942 non-null   object
#  19  homepage                             28 non-null     object
#  20  imdb_id                              1942 non-null   object
#  21  origin_country                       1942 non-null   object
#  22  original_language                    1942 non-null   object
#  23  original_title                       1942 non-null   object
#  24  overview                             1843 non-null   object
#  25  popularity                           1942 non-null   float64
#  26  poster_path                          1942 non-null   object
#  27  production_companies                 1942 non-null   object
#  28  production_countries                 1942 non-null   object
#  29  release_date                         1942 non-null   object
#  30  revenue                              1942 non-null   object
#  31  runtime                              1942 non-null   object
#  32  spoken_languages                     1942 non-null   object
#  33  status                               1942 non-null   object
#  34  tagline                              888 non-null    object
#  35  title                                1942 non-null   object
#  36  video                                1942 non-null   object
#  37  vote_average                         1942 non-null   float64
#  38  vote_count                           1942 non-null   Int64
#  39  credits.cast                         1942 non-null   object
#  40  credits.crew                         1942 non-null   object
#  41  keywords.keywords                    1942 non-null   object
#  42  release_dates.results                1942 non-null   object
#  43  belongs_to_collection.id             217 non-null    float64
#  44  belongs_to_collection.name           217 non-null    object
#  45  belongs_to_collection.poster_path    205 non-null    object
#  46  belongs_to_collection.backdrop_path  185 non-null    object
#  47  fonte_origem                         1942 non-null   object
# dtypes: Int64(4), float64(6), object(38)
# memory usage: 751.0+ KB

# %%
# Garantir que anoLancamento seja inteiro
df_refined['anoLancamento'] = df_refined['anoLancamento'].astype('Int64')

# Garantir que tempoMinutos seja inteiro (pode ter valores nulos)
df_refined['tempoMinutos'] = df_refined['tempoMinutos'].astype('Int64')

# Nota média e número de votos do CSV
df_refined['notaMedia'] = df_refined['notaMedia'].astype(float)
df_refined['numeroVotos'] = df_refined['numeroVotos'].astype('Int64')

# vote_average e vote_count do TMDB
df_refined['vote_average'] = df_refined['vote_average'].astype(float)
df_refined['vote_count'] = df_refined['vote_count'].astype('Int64')

# %%
df_refined['release_date'] = pd.to_datetime(df_refined['release_date'], errors='coerce')
df_refined['ano_lancamento_tmdb'] = df_refined['release_date'].dt.year.astype('Int64')

# %%
import ast

def parse_json_column(col):
    return col.apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

colunas_json = [
    'genres', 'keywords.keywords', 'credits.cast', 'credits.crew',
    'production_companies', 'production_countries', 'release_dates.results'
]

for col in colunas_json:
    if col in df_refined.columns:
        df_refined[col] = parse_json_column(df_refined[col])

# %%
# Verificar colunas críticas
print(df_refined[['imdb_id', 'tituloOriginal', 'anoLancamento', 'notaMedia', 'vote_average', 'release_date']].isnull().sum())
# Out:
# imdb_id           0
# tituloOriginal    0
# anoLancamento     0
# notaMedia         0
# vote_average      0
# release_date      0
# dtype: int64

# %%
# Ver informações gerais (colunas, tipos e valores ausentes)
df_refined.info()

# Identificar colunas que não possuem listas ou dicionários (evita erro no nunique)
colunas_sem_estruturas_complexas = [
    col for col in df_refined.columns
    if df_refined[col].apply(lambda x: isinstance(x, (list, dict))).sum() == 0
]

# Mostrar as colunas com maior número de valores únicos (entre as simples)
print("\n🔍 Principais colunas com valores únicos:")
print(df_refined[colunas_sem_estruturas_complexas].nunique().sort_values(ascending=False).head(15))

# Exibir amostra dos dados
print("\n🧪 Amostra dos dados:")
display(df_refined[colunas_sem_estruturas_complexas].head(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1942 entries, 0 to 1941
# Data columns (total 49 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   tituloPincipal                       1942 non-null   object
#  1   tituloOriginal                       1942 non-null   object
#  2   anoLancamento                        1942 non-null   Int64
#  3   tempoMinutos                         1942 non-null   Int64
#  4   genero                               1942 non-null   object
#  5   notaMedia                            1942 non-null   float64
#  6   numeroVotos                          1942 non-null   Int64
#  7   generoArtista                        1942 non-null   object
#  8   personagem                           1929 non-null   object
#  9   nomeArtista                          1942 non-null   object
#  10  anoNascimento                        1758 non-null   float64
#  11  anoFalecimento                       445 non-null    float64
#  12  profissao                            1935 non-null   object
#  13  titulosMaisConhecidos                1942 non-null   object
#  14  adult                                1942 non-null   object
#  15  backdrop_path                        1942 non-null   object
#  16  belongs_to_collection                0 non-null      object
#  17  budget                               1942 non-null   object
#  18  genres                               1942 non-null   object
#  19  homepage                             28 non-null     object
#  20  imdb_id                              1942 non-null   object
#  21  origin_country                       1942 non-null   object
#  22  original_language                    1942 non-null   object
#  23  original_title                       1942 non-null   object
#  24  overview                             1843 non-null   object
#  25  popularity                           1942 non-null   float64
#  26  poster_path                          1942 non-null   object
#  27  production_companies                 1942 non-null   object
#  28  production_countries                 1942 non-null   object
#  29  release_date                         1942 non-null   datetime64[ns]
#  30  revenue                              1942 non-null   object
#  31  runtime                              1942 non-null   object
#  32  spoken_languages                     1942 non-null   object
#  33  status                               1942 non-null   object
#  34  tagline                              888 non-null    object
#  35  title                                1942 non-null   object
#  36  video                                1942 non-null   object
#  37  vote_average                         1942 non-null   float64
#  38  vote_count                           1942 non-null   Int64
#  39  credits.cast                         1942 non-null   object
#  40  credits.crew                         1942 non-null   object
#  41  keywords.keywords                    1942 non-null   object
#  42  release_dates.results                1942 non-null   object
#  43  belongs_to_collection.id             217 non-null    float64
#  44  belongs_to_collection.name           217 non-null    object
#  45  belongs_to_collection.poster_path    205 non-null    object
#  46  belongs_to_collection.backdrop_path  185 non-null    object
#  47  fonte_origem                         1942 non-null   object
#  48  ano_lancamento_tmdb                  1942 non-null   Int64
# dtypes: Int64(5), datetime64[ns](1), float64(6), object(37)
# memory usage: 768.1+ KB
#
# 🔍 Principais colunas com valores únicos:
# personagem               1861
# nomeArtista              1613
# titulosMaisConhecidos    1606
# numeroVotos               486
# imdb_id                   486
# backdrop_path             486
# poster_path               486
# title                     485
# original_title            484
# tituloOriginal            482
# tituloPincipal            482
# popularity                481
# release_date              472
# overview                  461
# vote_count                375
# dtype: int64
#
# 🧪 Amostra dos dados:
#                tituloPincipal                   tituloOriginal  anoLancamento  \
# 0  Captain Horatio Hornblower  Captain Horatio Hornblower R.N.           1951
# 1  Captain Horatio Hornblower  Captain Horatio Hornblower R.N.           1951
# 2  Captain Horatio Hornblower  Captain Horatio Hornblower R.N.           1951
#
#    tempoMinutos                  genero  notaMedia  numeroVotos generoArtista  \
# 0           117  Action,Adventure,Drama        7.3         6851         actor
# 1           117  Action,Adventure,Drama        7.3         6851       actress
# 2           117  Action,Adventure,Drama        7.3         6851         actor
#
#                      personagem    nomeArtista  ...             title  video  \
# 0  Capt. Horatio Hornblower R.N   Gregory Peck  ...  Falcão dos Mares  False
# 1        Lady Barbara Wellesley  Virginia Mayo  ...  Falcão dos Mares  False
# 2              Lt. William Bush  Robert Beatty  ...  Falcão dos Mares  False
#
#   vote_average vote_count belongs_to_collection.id belongs_to_collection.name  \
# 0          6.9        124                      NaN                        NaN
# 1          6.9        124                      NaN                        NaN
# 2          6.9        124                      NaN                        NaN
#
#   belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
#
#   fonte_origem ano_lancamento_tmdb
# 0     csv+tmdb                1951
# 1     csv+tmdb                1951
# 2     csv+tmdb                1951
#
# [3 rows x 42 columns]

# %% [markdown]
# criando a tabela fato

# %%
# Copiar o DataFrame base
df_fato_filmes = df_refined.copy()

# Criar colunas derivadas
df_fato_filmes['id_filme'] = df_fato_filmes['imdb_id']
df_fato_filmes['decada'] = df_fato_filmes['anoLancamento'] // 10 * 10

# Normalizar colunas de gênero
# Se "genres" da TMDB estiver disponível, usa ele; senão, usa o do CSV
def extrair_generos(row):
    try:
        if isinstance(row['genres'], str) and row['genres'].startswith('['):
            # formato da API: "[{'id': ..., 'name': 'War'}]"
            import ast
            gen_list = ast.literal_eval(row['genres'])
            return ','.join([g['name'] for g in gen_list if 'name' in g])
        elif pd.notnull(row['genero']):
            return row['genero']
        else:
            return pd.NA
    except:
        return pd.NA

df_fato_filmes['generos'] = df_fato_filmes.apply(extrair_generos, axis=1)

# Padronizar duração
def obter_duracao(row):
    if pd.notnull(row['tempoMinutos']):
        return row['tempoMinutos']
    try:
        return int(row['runtime'])
    except:
        return pd.NA

df_fato_filmes['duracao'] = df_fato_filmes.apply(obter_duracao, axis=1)

# Selecionar e renomear as colunas da fato
fato_filmes = df_fato_filmes[[
    'id_filme',
    'tituloPincipal',
    'anoLancamento',
    'decada',
    'generos',
    'notaMedia',
    'numeroVotos',
    'budget',
    'revenue',
    'duracao',
    'original_language',
    'fonte_origem'
]].rename(columns={
    'tituloPincipal': 'titulo',
    'anoLancamento': 'ano_lancamento',
    'notaMedia': 'nota_media',
    'numeroVotos': 'numero_votos',
    'budget': 'orcamento',
    'revenue': 'receita',
    'original_language': 'idioma_original'
})

# Verificar o resultado
print("✅ Tabela fato_filmes gerada com sucesso!")
display(fato_filmes.head(3))
print("\n📏 Formato:", fato_filmes.shape)
print("🧩 Valores ausentes por coluna:")
display(fato_filmes.isnull().sum())
# Out:
# ✅ Tabela fato_filmes gerada com sucesso!
#     id_filme                      titulo  ano_lancamento  decada  \
# 0  tt0043379  Captain Horatio Hornblower            1951    1950
# 1  tt0043379  Captain Horatio Hornblower            1951    1950
# 2  tt0043379  Captain Horatio Hornblower            1951    1950
#
#                   generos  nota_media  numero_votos orcamento receita  \
# 0  Action,Adventure,Drama         7.3          6851         0       0
# 1  Action,Adventure,Drama         7.3          6851         0       0
# 2  Action,Adventure,Drama         7.3          6851         0       0
#
#    duracao idioma_original fonte_origem
# 0      117              en     csv+tmdb
# 1      117              en     csv+tmdb
# 2      117              en     csv+tmdb
# 📏 Formato: (1942, 12)
# 🧩 Valores ausentes por coluna:
# id_filme           0
# titulo             0
# ano_lancamento     0
# decada             0
# generos            0
# nota_media         0
# numero_votos       0
# orcamento          0
# receita            0
# duracao            0
# idioma_original    0
# fonte_origem       0
# dtype: int64

# %% [markdown]
# tabela fato final (com valores unicos)

# %%
fato_filmes_final = fato_filmes.drop_duplicates(subset='id_filme')
print("🎬 Total de filmes únicos na tabela fato:", fato_filmes_final.shape[0])
# Out:
# 🎬 Total de filmes únicos na tabela fato: 486

# %% [markdown]
# vendo p orcamento e receita diferente de zero

# %%
# Garantir que estamos trabalhando com uma cópia segura do dataframe tratado
df_base = df_refined.copy()

# ✅ Conversões seguras para orçamento e receita (usando NaN em vez de 0 para ausentes)
df_base['orcamento'] = pd.to_numeric(df_base['budget'], errors='coerce')
df_base['receita'] = pd.to_numeric(df_base['revenue'], errors='coerce')

# ✅ Geração da coluna 'decada'
df_base['decada'] = (df_base['ano_lancamento'] // 10) * 10

# ✅ Construção da tabela fato
fato_filmes = pd.DataFrame({
    'id_filme': df_base['imdb_id'],
    'titulo': df_base['tituloPincipal'],
    'ano_lancamento': df_base['ano_lancamento'],
    'decada': df_base['decada'],
    'generos': df_base['genero'],
    'nota_media': df_base['notaMedia'],
    'numero_votos': df_base['numeroVotos'],
    'orcamento': df_base['orcamento'],
    'receita': df_base['receita'],
    'duracao': df_base['tempoMinutos'],
    'idioma_original': df_base['original_language'],
    'fonte_origem': df_base['fonte_origem']
})

# ✅ Remover duplicatas (uma linha por filme)
fato_filmes_final = fato_filmes.drop_duplicates(subset='id_filme')

# ✅ Verificações
print("🎬 Total de filmes únicos na tabela fato:", fato_filmes_final.shape[0])
print("\n📏 Formato final:", fato_filmes_final.shape)
print("\n🧩 Valores ausentes por coluna:")
print(fato_filmes_final.isnull().sum())
print("\n🧪 Amostra:")
display(fato_filmes_final.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ano_lancamento'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 9
#       6 df_base['receita'] = pd.to_numeric(df_base['revenue'], errors='coerce')
#       8 # ✅ Geração da coluna 'decada'
# ----> 9 df_base['decada'] = (df_base['ano_lancamento'] // 10) * 10
#      11 # ✅ Construção da tabela fato
#      12 fato_filmes = pd.DataFrame({
#      13     'id_filme': df_base['imdb_id'],
#      14     'titulo': df_base['tituloPincipal'],
#    (...)
#      24     'fonte_origem': df_base['fonte_origem']
#      25 })
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ano_lancamento'

# %%
import pandas as pd
import ast

# Copiar o DataFrame base
df_fato_filmes = df_refined.copy()

# Criar colunas derivadas
df_fato_filmes['id_filme'] = df_fato_filmes['imdb_id']
df_fato_filmes['decada'] = (df_fato_filmes['anoLancamento'] // 10) * 10

# Normalizar colunas de gênero
def extrair_generos(row):
    try:
        if isinstance(row['genres'], str) and row['genres'].startswith('['):
            # Formato API: lista de dicts, extrair nome dos gêneros
            gen_list = ast.literal_eval(row['genres'])
            return ','.join([g['name'] for g in gen_list if 'name' in g])
        elif pd.notnull(row['genero']):
            return row['genero']
        else:
            return pd.NA
    except:
        return pd.NA

df_fato_filmes['generos'] = df_fato_filmes.apply(extrair_generos, axis=1)

# Padronizar duração
def obter_duracao(row):
    if pd.notnull(row['tempoMinutos']):
        return row['tempoMinutos']
    try:
        return int(row['runtime'])
    except:
        return pd.NA

df_fato_filmes['duracao'] = df_fato_filmes.apply(obter_duracao, axis=1)

# Selecionar e renomear as colunas para a tabela fato
fato_filmes = df_fato_filmes[[
    'id_filme',
    'tituloPincipal',
    'anoLancamento',
    'decada',
    'generos',
    'notaMedia',
    'numeroVotos',
    'budget',
    'revenue',
    'duracao',
    'original_language',
    'fonte_origem'
]].rename(columns={
    'tituloPincipal': 'titulo',
    'anoLancamento': 'ano_lancamento',
    'notaMedia': 'nota_media',
    'numeroVotos': 'numero_votos',
    'budget': 'orcamento',
    'revenue': 'receita',
    'original_language': 'idioma_original'
})

# Verificar o resultado
print("✅ Tabela fato_filmes gerada com sucesso!")
display(fato_filmes.head(3))
print("\n📏 Formato:", fato_filmes.shape)
print("🧩 Valores ausentes por coluna:")
display(fato_filmes.isnull().sum())
# Out:
# ✅ Tabela fato_filmes gerada com sucesso!
#     id_filme                      titulo  ano_lancamento  decada  \
# 0  tt0043379  Captain Horatio Hornblower            1951    1950
# 1  tt0043379  Captain Horatio Hornblower            1951    1950
# 2  tt0043379  Captain Horatio Hornblower            1951    1950
#
#                   generos  nota_media  numero_votos orcamento receita  \
# 0  Action,Adventure,Drama         7.3          6851         0       0
# 1  Action,Adventure,Drama         7.3          6851         0       0
# 2  Action,Adventure,Drama         7.3          6851         0       0
#
#    duracao idioma_original fonte_origem
# 0      117              en     csv+tmdb
# 1      117              en     csv+tmdb
# 2      117              en     csv+tmdb
# 📏 Formato: (1942, 12)
# 🧩 Valores ausentes por coluna:
# id_filme           0
# titulo             0
# ano_lancamento     0
# decada             0
# generos            0
# nota_media         0
# numero_votos       0
# orcamento          0
# receita            0
# duracao            0
# idioma_original    0
# fonte_origem       0
# dtype: int64

# %% [markdown]
# orcamento e receita diferente de zero

# %%
import pandas as pd
import ast

# Copiar o DataFrame base
df_fato_filmes = df_refined.copy()

# Criar colunas derivadas
df_fato_filmes['id_filme'] = df_fato_filmes['imdb_id']
df_fato_filmes['decada'] = (df_fato_filmes['anoLancamento'] // 10) * 10

# Normalizar colunas de gênero
def extrair_generos(row):
    try:
        if isinstance(row['genres'], str) and row['genres'].startswith('['):
            # Formato API: lista de dicts, extrair nome dos gêneros
            gen_list = ast.literal_eval(row['genres'])
            return ','.join([g['name'] for g in gen_list if 'name' in g])
        elif pd.notnull(row['genero']):
            return row['genero']
        else:
            return pd.NA
    except:
        return pd.NA

df_fato_filmes['generos'] = df_fato_filmes.apply(extrair_generos, axis=1)

# Padronizar duração
def obter_duracao(row):
    if pd.notnull(row['tempoMinutos']):
        return row['tempoMinutos']
    try:
        return int(row['runtime'])
    except:
        return pd.NA

df_fato_filmes['duracao'] = df_fato_filmes.apply(obter_duracao, axis=1)

# Converter orçamento e receita para numérico e substituir zeros por NA
df_fato_filmes['orcamento'] = pd.to_numeric(df_fato_filmes['budget'], errors='coerce')
df_fato_filmes['receita'] = pd.to_numeric(df_fato_filmes['revenue'], errors='coerce')

df_fato_filmes.loc[df_fato_filmes['orcamento'] == 0, 'orcamento'] = pd.NA
df_fato_filmes.loc[df_fato_filmes['receita'] == 0, 'receita'] = pd.NA

# Selecionar e renomear as colunas para a tabela fato
fato_filmes = df_fato_filmes[[
    'id_filme',
    'tituloPincipal',
    'anoLancamento',
    'decada',
    'generos',
    'notaMedia',
    'numeroVotos',
    'orcamento',
    'receita',
    'duracao',
    'original_language',
    'fonte_origem'
]].rename(columns={
    'tituloPincipal': 'titulo',
    'anoLancamento': 'ano_lancamento',
    'notaMedia': 'nota_media',
    'numeroVotos': 'numero_votos',
    'original_language': 'idioma_original'
})

# Verificar o resultado
print("✅ Tabela fato_filmes gerada com sucesso!")
display(fato_filmes.head(3))
print("\n📏 Formato:", fato_filmes.shape)
print("🧩 Valores ausentes por coluna:")
display(fato_filmes.isnull().sum())
# Out:
# ✅ Tabela fato_filmes gerada com sucesso!
#     id_filme                      titulo  ano_lancamento  decada  \
# 0  tt0043379  Captain Horatio Hornblower            1951    1950
# 1  tt0043379  Captain Horatio Hornblower            1951    1950
# 2  tt0043379  Captain Horatio Hornblower            1951    1950
#
#                   generos  nota_media  numero_votos  orcamento  receita  \
# 0  Action,Adventure,Drama         7.3          6851        NaN      NaN
# 1  Action,Adventure,Drama         7.3          6851        NaN      NaN
# 2  Action,Adventure,Drama         7.3          6851        NaN      NaN
#
#    duracao idioma_original fonte_origem
# 0      117              en     csv+tmdb
# 1      117              en     csv+tmdb
# 2      117              en     csv+tmdb
# 📏 Formato: (1942, 12)
# 🧩 Valores ausentes por coluna:
# id_filme             0
# titulo               0
# ano_lancamento       0
# decada               0
# generos              0
# nota_media           0
# numero_votos         0
# orcamento          705
# receita            668
# duracao              0
# idioma_original      0
# fonte_origem         0
# dtype: int64

# %%
# Remover linhas duplicadas por id_filme, mantendo a primeira ocorrência
fato_filmes_final = fato_filmes.drop_duplicates(subset='id_filme').reset_index(drop=True)

print("🎬 Total de filmes únicos na tabela fato:", fato_filmes_final.shape[0])

# Visualizar algumas linhas para conferir
display(fato_filmes_final.head())
# Out:
# 🎬 Total de filmes únicos na tabela fato: 486
#     id_filme                               titulo  ano_lancamento  decada  \
# 0  tt0043379           Captain Horatio Hornblower            1951    1950
# 1  tt0043461  The Desert Fox: The Story of Rommel            1951    1950
# 2  tt0043686                      Forbidden Games            1952    1950
# 3  tt0044602                     Fanfan la Tulipe            1952    1950
# 4  tt0045793                From Here to Eternity            1953    1950
#
#                     generos  nota_media  numero_votos  orcamento     receita  \
# 0    Action,Adventure,Drama         7.3          6851        NaN         NaN
# 1       Biography,Drama,War         6.9          6362        NaN         NaN
# 2          Comedy,Drama,War         8.0         12414        NaN     10188.0
# 3  Adventure,Comedy,Romance         7.2          3120        NaN         NaN
# 4         Drama,Romance,War         7.6         47555  1650000.0  30500000.0
#
#    duracao idioma_original fonte_origem
# 0      117              en     csv+tmdb
# 1       88              en     csv+tmdb
# 2       86              fr     csv+tmdb
# 3      102              fr     csv+tmdb
# 4      118              en     csv+tmdb

# %% [markdown]
# conferindo os daaddos faltantes e filmes q n temm guerra

# %%
# 1. Verificar valores ausentes na tabela fato final
print("🧩 Valores ausentes por coluna na tabela fato final:")
print(fato_filmes_final.isnull().sum())

# 2. Confirmar que todos os filmes possuem o gênero "War" na coluna generos
# Aqui vamos ver quantos filmes não têm "War" no campo generos (caso haja algum erro)
filmes_sem_guerra = fato_filmes_final[~fato_filmes_final['generos'].str.contains('War', case=False, na=False)]

print(f"\n🎯 Filmes sem gênero 'War' na tabela fato final: {filmes_sem_guerra.shape[0]}")

if filmes_sem_guerra.shape[0] > 0:
    print("\nExemplo desses filmes:")
    display(filmes_sem_guerra[['id_filme', 'titulo', 'generos']].head())
else:
    print("✅ Todos os filmes possuem o gênero 'War'.")
# Out:
# 🧩 Valores ausentes por coluna na tabela fato final:
# id_filme             0
# titulo               0
# ano_lancamento       0
# decada               0
# generos              0
# nota_media           0
# numero_votos         0
# orcamento          177
# receita            168
# duracao              0
# idioma_original      0
# fonte_origem         0
# dtype: int64
#
# 🎯 Filmes sem gênero 'War' na tabela fato final: 238
#
# Exemplo desses filmes:
#      id_filme                      titulo                   generos
# 0   tt0043379  Captain Horatio Hornblower    Action,Adventure,Drama
# 3   tt0044602            Fanfan la Tulipe  Adventure,Comedy,Romance
# 12  tt0049233         Friendly Persuasion      Drama,Family,Romance
# 15  tt0050356             The Enemy Below    Action,Adventure,Drama
# 33  tt0053580                   The Alamo   Adventure,Drama,History

# %%
# 1. Verifique se a string "War" está contida na coluna generos (depois da limpeza que fizemos)
filtro_war_tmdb = df_refined['generos'].str.contains('War', na=False)

# 2. Verifique se a string "War" está presente na coluna genero (do CSV original)
filtro_war_csv = df_refined['genero'].str.contains('War', na=False)

# 3. Casos onde o TMDB considera "War", mas o CSV não
filtro_divergente = filtro_war_tmdb & (~filtro_war_csv)

# 4. Aplicar o filtro e exibir
filmes_divergentes = df_refined[filtro_divergente][['id_filme', 'tituloPincipal', 'genero', 'generos', 'fonte_origem']].drop_duplicates()

print(f"🔍 Total de filmes com gênero 'War' no TMDB mas não no CSV: {filmes_divergentes.shape[0]}")
display(filmes_divergentes.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'generos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 # 1. Verifique se a string "War" está contida na coluna generos (depois da limpeza que fizemos)
# ----> 2 filtro_war_tmdb = df_refined['generos'].str.contains('War', na=False)
#       4 # 2. Verifique se a string "War" está presente na coluna genero (do CSV original)
#       5 filtro_war_csv = df_refined['genero'].str.contains('War', na=False)
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'generos'

# %%
import ast

def extrair_generos(row):
    try:
        if isinstance(row['genres'], str) and row['genres'].startswith('['):
            gen_list = ast.literal_eval(row['genres'])
            return ','.join([g['name'] for g in gen_list if 'name' in g])
        elif pd.notnull(row['genero']):
            return row['genero']
        else:
            return pd.NA
    except:
        return pd.NA

# Criar a coluna 'generos'
df_refined['generos'] = df_refined.apply(extrair_generos, axis=1)

# %%
# Verificação entre TMDB e CSV
filtro_war_tmdb = df_refined['generos'].str.contains('War', na=False)
filtro_war_csv = df_refined['genero'].str.contains('War', na=False)
filtro_divergente = filtro_war_tmdb & (~filtro_war_csv)

# Visualizar divergências
filmes_divergentes = df_refined[filtro_divergente][['id_filme', 'tituloPincipal', 'genero', 'generos', 'fonte_origem']].drop_duplicates()

print(f"🔍 Total de filmes com gênero 'War' no TMDB mas não no CSV: {filmes_divergentes.shape[0]}")
display(filmes_divergentes.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 7
#       4 filtro_divergente = filtro_war_tmdb & (~filtro_war_csv)
#       6 # Visualizar divergências
# ----> 7 filmes_divergentes = df_refined[filtro_divergente][['id_filme', 'tituloPincipal', 'genero', 'generos', 'fonte_origem']].drop_duplicates()
#       9 print(f"🔍 Total de filmes com gênero 'War' no TMDB mas não no CSV: {filmes_divergentes.shape[0]}")
#      10 display(filmes_divergentes.head(10))
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\luiza\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['id_filme'] not in index"

# %%
df_refined['id_filme'] = df_refined['imdb_id']

# %%
# Filtros para identificar divergência entre TMDB e CSV
filtro_war_tmdb = df_refined['generos'].str.contains('War', na=False)
filtro_war_csv = df_refined['genero'].str.contains('War', na=False)
filtro_divergente = filtro_war_tmdb & (~filtro_war_csv)

# Visualização dos filmes divergentes
filmes_divergentes = df_refined[filtro_divergente][[
    'id_filme', 'tituloPincipal', 'genero', 'generos', 'fonte_origem'
]].drop_duplicates()

print(f"🔍 Total de filmes com gênero 'War' no TMDB mas não no CSV: {filmes_divergentes.shape[0]}")
display(filmes_divergentes.head(10))
# Out:
# 🔍 Total de filmes com gênero 'War' no TMDB mas não no CSV: 0
# Empty DataFrame
# Columns: [id_filme, tituloPincipal, genero, generos, fonte_origem]
# Index: []

# %%
# Verifica filmes com "War" no CSV mas não no TMDB
filtro_war_csv = df_refined['genero'].str.contains('War', na=False)
filtro_war_tmdb = df_refined['generos'].str.contains('War', na=False)
filtro_divergente_csv = filtro_war_csv & (~filtro_war_tmdb)

filmes_divergentes_csv = df_refined[filtro_divergente_csv][[
    'id_filme', 'tituloPincipal', 'genero', 'generos', 'fonte_origem'
]].drop_duplicates()

print(f"📌 Filmes com 'War' no CSV mas não no TMDB: {filmes_divergentes_csv.shape[0]}")
display(filmes_divergentes_csv.head(10))
# Out:
# 📌 Filmes com 'War' no CSV mas não no TMDB: 0
# Empty DataFrame
# Columns: [id_filme, tituloPincipal, genero, generos, fonte_origem]
# Index: []

# %%
total_filmes_guerra = df_refined['id_filme'].nunique()
print(f"🎬 Total de filmes de guerra únicos na base: {total_filmes_guerra}")
# Out:
# 🎬 Total de filmes de guerra únicos na base: 486

# %%
filmes_guerra_confirmados = df_refined[df_refined['generos'].str.contains('War', na=False)]
print(f"🎯 Filmes com gênero 'War' confirmado: {filmes_guerra_confirmados['id_filme'].nunique()}")
# Out:
# 🎯 Filmes com gênero 'War' confirmado: 248

# %%
filmes_guerra_por_fonte = df_refined[['id_filme', 'fonte_origem']].drop_duplicates()
print("📊 Quantidade de filmes de guerra por fonte de origem:")
print(filmes_guerra_por_fonte['fonte_origem'].value_counts())
# Out:
# 📊 Quantidade de filmes de guerra por fonte de origem:
# fonte_origem
# csv+tmdb    486
# Name: count, dtype: int64

# %%
# Garantir base dos 486 válidos
df_base = df_refined[df_refined['fonte_origem'] == 'csv+tmdb'].copy()

# Filmes onde 'generos' não contém 'War'
filtro_nao_war = ~df_base['generos'].str.contains('War', na=False)

# Aplicar filtro
filmes_suspeitos = df_base[filtro_nao_war].copy()

# Converter colunas problemáticas para string para evitar erro de unhashable
colunas_para_ver = ['id_filme', 'tituloPincipal', 'genero', 'genres', 'generos']
filmes_suspeitos[colunas_para_ver] = filmes_suspeitos[colunas_para_ver].astype(str)

# Exibir resultado
print(f"🎯 Filmes com fonte 'csv+tmdb' mas sem 'War' no campo generos: {filmes_suspeitos.shape[0]}")
display(filmes_suspeitos[colunas_para_ver].drop_duplicates().head(10))
# Out:
# 🎯 Filmes com fonte 'csv+tmdb' mas sem 'War' no campo generos: 956
#       id_filme              tituloPincipal                     genero  \
# 0    tt0043379  Captain Horatio Hornblower     Action,Adventure,Drama
# 12   tt0044602            Fanfan la Tulipe   Adventure,Comedy,Romance
# 48   tt0049233         Friendly Persuasion       Drama,Family,Romance
# 60   tt0050356             The Enemy Below     Action,Adventure,Drama
# 130  tt0053580                   The Alamo    Adventure,Drama,History
# 142  tt0054310          Sink the Bismarck!       Action,Drama,History
# 146  tt0054331                   Spartacus  Adventure,Biography,Drama
# 162  tt0054847                      El Cid    Biography,Drama,History
# 166  tt0054953        The Guns of Navarone     Action,Adventure,Drama
# 174  tt0055719            The 300 Spartans    Adventure,Drama,History
#
#                                                 genres  \
# 0    [{'id': 12, 'name': 'Aventura'}, {'id': 10752,...
# 12   [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...
# 48   [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 60                   [{'id': 10752, 'name': 'Guerra'}]
# 130  [{'id': 10752, 'name': 'Guerra'}, {'id': 12, '...
# 142  [{'id': 10752, 'name': 'Guerra'}, {'id': 18, '...
# 146  [{'id': 36, 'name': 'História'}, {'id': 10752,...
# 162  [{'id': 28, 'name': 'Ação'}, {'id': 18, 'name'...
# 166  [{'id': 10752, 'name': 'Guerra'}, {'id': 12, '...
# 174  [{'id': 12, 'name': 'Aventura'}, {'id': 36, 'n...
#
#                        generos
# 0       Action,Adventure,Drama
# 12    Adventure,Comedy,Romance
# 48        Drama,Family,Romance
# 60      Action,Adventure,Drama
# 130    Adventure,Drama,History
# 142       Action,Drama,History
# 146  Adventure,Biography,Drama
# 162    Biography,Drama,History
# 166     Action,Adventure,Drama
# 174    Adventure,Drama,History

# %%
import ast

def reconstruir_generos(row):
    try:
        if isinstance(row['genres'], str) and row['genres'].startswith('['):
            lista = ast.literal_eval(row['genres'])
            nomes_ingles = [g['name'] for g in lista if 'name' in g]
            return ','.join(nomes_ingles)
        elif pd.notnull(row['genero']):
            return row['genero']
        else:
            return pd.NA
    except:
        return pd.NA

# Aplicar no df_refined
df_refined['generos'] = df_refined.apply(reconstruir_generos, axis=1)

# %%
# Checar se "War" aparece corretamente agora
filtro_war = df_refined['generos'].str.contains('War', na=False)
df_war_final = df_refined[filtro_war]

print("🎯 Total de filmes com 'War' na coluna generos:", df_war_final['id_filme'].nunique())
# Out:
# 🎯 Total de filmes com 'War' na coluna generos: 248

# %%
import ast

# Mapeamento dos gêneros mais comuns (do TMDB em pt → en)
mapeamento_generos = {
    'Ação': 'Action',
    'Aventura': 'Adventure',
    'Animação': 'Animation',
    'Comédia': 'Comedy',
    'Crime': 'Crime',
    'Documentário': 'Documentary',
    'Drama': 'Drama',
    'Família': 'Family',
    'Fantasia': 'Fantasy',
    'História': 'History',
    'Terror': 'Horror',
    'Música': 'Music',
    'Mistério': 'Mystery',
    'Romance': 'Romance',
    'Ficção científica': 'Science Fiction',
    'Cinema TV': 'TV Movie',
    'Thriller': 'Thriller',
    'Guerra': 'War',
    'Faroeste': 'Western'
}

def reconstruir_generos_traduzido(row):
    try:
        if isinstance(row['genres'], str) and row['genres'].startswith('['):
            lista = ast.literal_eval(row['genres'])
            nomes_traduzidos = [mapeamento_generos.get(g['name'], g['name']) for g in lista if 'name' in g]
            return ','.join(nomes_traduzidos)
        elif pd.notnull(row['genero']):
            return row['genero']
        else:
            return pd.NA
    except:
        return pd.NA

# Atualiza a coluna 'generos' com nomes traduzidos
df_refined['generos'] = df_refined.apply(reconstruir_generos_traduzido, axis=1)

# %%
filtro_war = df_refined['generos'].str.contains('War', na=False)
df_war_final = df_refined[filtro_war]

print("🎯 Total de filmes com 'War' na coluna generos (com tradução):", df_war_final['id_filme'].nunique())
# Out:
# 🎯 Total de filmes com 'War' na coluna generos (com tradução): 248

# %%
# Filmes com 'Guerra' no campo 'genres' bruto do TMDB
tmdb_guerra_raw = df_refined[df_refined['genres'].str.contains("'name': 'Guerra'", na=False)]
print("🎯 Total de filmes com 'Guerra' no campo bruto 'genres':", tmdb_guerra_raw['id_filme'].nunique())
# Out:
# 🎯 Total de filmes com 'Guerra' no campo bruto 'genres': 0

# %%
print("Exemplo de tipo:", type(df_refined.loc[0, 'genres']))
print("Valor:", df_refined.loc[0, 'genres'])
# Out:
# Exemplo de tipo: <class 'list'>
# Valor: [{'id': 12, 'name': 'Aventura'}, {'id': 10752, 'name': 'Guerra'}, {'id': 36, 'name': 'História'}]

# %%
# Mapeamento traduzido
mapeamento_generos = {
    'Action': 'Ação',
    'Adventure': 'Aventura',
    'Animation': 'Animação',
    'Comedy': 'Comédia',
    'Crime': 'Crime',
    'Documentary': 'Documentário',
    'Drama': 'Drama',
    'Family': 'Família',
    'Fantasy': 'Fantasia',
    'History': 'História',
    'Horror': 'Terror',
    'Music': 'Música',
    'Mystery': 'Mistério',
    'Romance': 'Romance',
    'Science Fiction': 'Ficção científica',
    'TV Movie': 'Filme de TV',
    'Thriller': 'Suspense',
    'War': 'Guerra',
    'Western': 'Faroeste'
}

# Função robusta para extrair e traduzir os gêneros
def reconstruir_generos_traduzido(row):
    try:
        generos_traduzidos = []

        # Caso 1: genres já é lista (vindo da API TMDB tratada)
        if isinstance(row['genres'], list):
            generos_traduzidos = [mapeamento_generos.get(g['name'], g['name']) for g in row['genres'] if 'name' in g]

        # Caso 2: genres é string parecida com lista
        elif isinstance(row['genres'], str) and row['genres'].startswith('['):
            import ast
            lista = ast.literal_eval(row['genres'])
            generos_traduzidos = [mapeamento_generos.get(g['name'], g['name']) for g in lista if 'name' in g]

        # Caso 3: usar 'genero' do CSV como fallback
        elif pd.notnull(row.get('genero')):
            return row['genero']

        return ','.join(generos_traduzidos) if generos_traduzidos else pd.NA

    except Exception:
        return pd.NA

# Aplicar ao DataFrame
df_refined['generos'] = df_refined.apply(reconstruir_generos_traduzido, axis=1)

# %%
qtd_war = df_refined[df_refined['generos'].str.contains('Guerra', na=False)].shape[0]
print(f"🎯 Total de filmes com gênero 'Guerra' agora corretamente identificados: {qtd_war}")
# Out:
# 🎯 Total de filmes com gênero 'Guerra' agora corretamente identificados: 1942

# %% [markdown]
# entendi o erro e vou voltar a tratara a tabela fato

# %% [markdown]
# 3. Código para extrair e padronizar os gêneros em ambos:

# %%
import pandas as pd
import ast

# Exemplo carregando os CSVs (supondo pipe para movies.csv)
df_movies = pd.read_csv('movies.csv', sep='|', na_values='\\N')
df_tmdb = pd.read_csv('filmes_guerra_detalhes.csv')

# Função para extrair gênero do movies.csv (string simples)
def extrair_generos_csv(gen):
    if pd.isna(gen):
        return []
    # separa por vírgula e remove espaços
    return [g.strip() for g in gen.split(',')]

# Função para extrair gênero do tmdb.csv (string json de lista de dicts)
def extrair_generos_tmdb(gen_str):
    try:
        # converte string para lista de dicts
        gen_list = ast.literal_eval(gen_str)
        # extrai os nomes dos gêneros
        return [g['name'] for g in gen_list]
    except:
        return []

# Criar coluna genres_padronizado nos dois dfs
df_movies['genres_padronizado'] = df_movies['genero'].apply(extrair_generos_csv)
df_tmdb['genres_padronizado'] = df_tmdb['genres'].apply(extrair_generos_tmdb)

# Exemplo: filtrar filmes de guerra (gênero "Guerra")
filmes_guerra_movies = df_movies[df_movies['genres_padronizado'].apply(lambda x: 'Guerra' in x)]
filmes_guerra_tmdb = df_tmdb[df_tmdb['genres_padronizado'].apply(lambda x: 'Guerra' in x)]

print(f"Filmes de guerra no CSV movies: {len(filmes_guerra_movies)}")
print(f"Filmes de guerra no CSV TMDB: {len(filmes_guerra_tmdb)}")
# Out:
# Filmes de guerra no CSV movies: 0
# Filmes de guerra no CSV TMDB: 574

# %%
print(df_movies['genero'].value_counts(dropna=False))
# Out:
# genero
# Drama                               209429
# Comedy                              103839
# Comedy,Drama                         39051
# NaN                                  38880
# Drama,Romance                        38132
# Horror                               29096
# Comedy,Romance                       23088
# Documentary                          18476
# Action                               18235
# Comedy,Drama,Romance                 17935
# Thriller                             17857
# Crime,Drama                          16099
# Western                              13911
# Drama,Thriller                       12529
# Action,Crime,Drama                   12397
# Romance                              11919
# Action,Drama                         11783
# Horror,Thriller                       9415
# Drama,War                             8443
# Crime,Drama,Thriller                  7744
# Adventure                             7665
# Drama,Family                          7628
# Crime                                 6475
# Comedy,Horror                         6159
# Family                                6093
# Action,Adventure,Drama                5383
# Comedy,Musical                        5225
# Action,Comedy                         5181
# Comedy,Crime                          4977
# Crime,Drama,Mystery                   4835
# Action,Thriller                       4740
# Drama,History                         4705
# Action,Adventure,Comedy               4650
# Comedy,Crime,Drama                    4496
# Action,Comedy,Crime                   4284
# Horror,Mystery,Thriller               4195
# Adventure,Drama                       4111
# Action,Crime,Thriller                 3937
# Biography,Drama                       3900
# Comedy,Drama,Family                   3829
# Sci-Fi                                3601
# Comedy,Family                         3544
# Crime,Thriller                        3505
# Action,Drama,Thriller                 3500
# Crime,Drama,Romance                   3468
# Drama,Mystery,Thriller                3402
# Musical                               3381
# Action,Crime                          3365
# Action,Comedy,Drama                   3347
# Action,Adventure                      3304
# Drama,Horror,Mystery                  3100
# Biography,Drama,History               3099
# Drama,Horror,Thriller                 3050
# Drama,Mystery                         3048
# Action,Drama,Romance                  3025
# Mystery                               2886
# Comedy,Musical,Romance                2843
# Adventure,Animation,Comedy            2725
# Drama,Music                           2656
# Animation                             2635
# Fantasy                               2585
# Drama,Horror                          2574
# Drama,Musical                         2537
# Action,Adventure,Crime                2519
# Mystery,Thriller                      2476
# Crime,Drama,Film-Noir                 2376
# Adventure,Comedy,Drama                2241
# Drama,Sport                           2236
# Comedy,Drama,Fantasy                  2236
# Comedy,Drama,Musical                  2229
# Comedy,Fantasy                        2220
# Comedy,Drama,Music                    2215
# Adventure,Comedy                      2204
# Action,Adventure,Animation            2188
# Drama,Fantasy                         2187
# Horror,Sci-Fi                         2177
# Drama,Romance,War                     2175
# War                                   2128
# Drama,Musical,Romance                 2086
# Adventure,Drama,Romance               1928
# Action,Adventure,Fantasy              1900
# Drama,Romance,Thriller                1895
# Horror,Mystery                        1772
# Comedy,Music                          1723
# Adventure,Comedy,Family               1712
# Drama,Music,Romance                   1704
# Crime,Mystery,Thriller                1701
# Comedy,Sci-Fi                         1701
# Drama,History,War                     1684
# Drama,Sci-Fi                          1658
# Adventure,Family                      1613
# Drama,Fantasy,Horror                  1575
# Action,Adventure,Sci-Fi               1473
# Drama,History,Romance                 1462
# Documentary,Drama                     1452
# Comedy,Thriller                       1384
# Drama,Mystery,Romance                 1379
# Crime,Drama,Horror                    1366
# Documentary,Music                     1334
# Action,Drama,History                  1291
# Action,Sci-Fi                         1288
# Adventure,Drama,Family                1272
# Adventure,Animation,Family            1260
# Action,Drama,War                      1257
# Comedy,Music,Romance                  1239
# Drama,Family,Romance                  1233
# Biography                             1230
# Adventure,Crime,Drama                 1182
# Musical,Romance                       1145
# Horror,Sci-Fi,Thriller                1128
# Comedy,Family,Fantasy                 1119
# History                               1118
# Drama,Western                         1096
# Action,Comedy,Romance                 1091
# Adventure,Family,Fantasy              1086
# Drama,Fantasy,Romance                 1062
# Action,Comedy,Horror                  1053
# Comedy,Sport                          1052
# Biography,Documentary                 1040
# Biography,Crime,Drama                 1029
# Comedy,Crime,Mystery                  1025
# Comedy,Fantasy,Romance                1013
# Comedy,Western                        1005
# Comedy,Fantasy,Horror                 1001
# Crime,Mystery                          994
# Comedy,Horror,Thriller                 970
# Family,Fantasy                         956
# Biography,Drama,Music                  945
# Music                                  940
# Adventure,Comedy,Crime                 938
# Comedy,Drama,Thriller                  932
# Sci-Fi,Thriller                        919
# Comedy,Drama,Mystery                   916
# Action,Horror,Thriller                 909
# Action,Sci-Fi,Thriller                 909
# Comedy,Horror,Sci-Fi                   905
# Action,Horror,Sci-Fi                   902
# Adventure,Fantasy                      889
# Action,Horror                          886
# Comedy,Drama,Horror                    878
# Action,Romance                         877
# Biography,Drama,Romance                870
# Comedy,Family,Romance                  869
# Action,Adventure,Romance               868
# Biography,Comedy,Drama                 859
# Action,Adventure,Thriller              855
# Crime,Horror,Thriller                  854
# Adventure,Drama,History                845
# Action,Comedy,Fantasy                  837
# Fantasy,Horror                         836
# Comedy,Crime,Romance                   831
# Drama,Fantasy,Mystery                  822
# Adventure,Comedy,Fantasy               820
# Animation,Family                       819
# Documentary,History                    808
# Adventure,Comedy,Romance               805
# Comedy,Mystery                         769
# Drama,Sci-Fi,Thriller                  752
# Comedy,Crime,Thriller                  750
# Crime,Horror,Mystery                   748
# Romance,Thriller                       724
# Adventure,Drama,Fantasy                703
# Documentary,Sport                      676
# Action,War                             672
# Action,Fantasy                         668
# Animation,Comedy,Family                653
# Action,Drama,Fantasy                   646
# Adventure,Crime                        644
# Biography,Documentary,History          640
# Comedy,Drama,Sport                     631
# Comedy,War                             629
# Adventure,Romance                      622
# Drama,Romance,Sport                    614
# Action,Adventure,Family                609
# Drama,Mystery,Sci-Fi                   608
# Action,Crime,Mystery                   601
# Comedy,Horror,Mystery                  593
# Comedy,Drama,History                   587
# Horror,Mystery,Sci-Fi                  587
# Action,Adventure,Horror                587
# Action,Drama,Horror                    586
# Biography,Drama,Sport                  579
# Drama,Horror,Sci-Fi                    570
# Action,Drama,Mystery                   568
# Adventure,Drama,Thriller               553
# Drama,Family,Fantasy                   551
# Drama,Family,Musical                   547
# Action,Biography,Drama                 542
# Action,Comedy,Thriller                 538
# Action,Drama,Sci-Fi                    535
# Action,Drama,Family                    533
# Action,Fantasy,Horror                  528
# Adventure,Western                      517
# Action,Drama,Sport                     511
# Fantasy,Horror,Mystery                 510
# Animation,Comedy,Drama                 508
# Biography,Documentary,Drama            493
# Comedy,Drama,War                       482
# Action,Animation,Drama                 478
# Comedy,Family,Musical                  476
# Comedy,Documentary                     472
# Adventure,Biography,Drama              463
# Comedy,Drama,Sci-Fi                    462
# Biography,Drama,War                    452
# Drama,Horror,Romance                   448
# Adventure,Drama,War                    447
# Crime,Horror                           424
# Drama,Thriller,War                     421
# Action,Comedy,Sci-Fi                   419
# Adventure,Animation,Drama              419
# Fantasy,Horror,Thriller                416
# Action,Animation,Comedy                408
# Action,Adventure,Western               399
# Drama,History,Thriller                 398
# Sport                                  388
# Action,Animation,Sci-Fi                384
# Action,Western                         378
# Crime,Drama,History                    371
# Drama,Romance,Sci-Fi                   371
# Crime,Drama,Music                      371
# Animation,Family,Fantasy               370
# Romance,Western                        364
# Action,Drama,Musical                   359
# Action,Crime,Horror                    358
# Adventure,Drama,Western                353
# Comedy,Crime,Horror                    349
# Animation,Comedy                       349
# Adventure,Animation,Fantasy            346
# Adventure,Sci-Fi                       345
# Adventure,History                      343
# Action,Mystery,Thriller                340
# Comedy,Crime,Family                    337
# Action,Drama,Western                   337
# Comedy,Romance,Sport                   336
# Comedy,Mystery,Thriller                334
# Action,Adventure,History               332
# Action,Adventure,Mystery               328
# Fantasy,Romance                        327
# Biography,Documentary,Music            320
# Comedy,History                         316
# Action,Adventure,War                   316
# Action,Fantasy,Sci-Fi                  305
# Biography,Drama,Family                 303
# Action,Crime,Romance                   300
# Action,Horror,Mystery                  299
# Drama,Fantasy,Sci-Fi                   297
# Comedy,Horror,Romance                  295
# Adventure,Drama,Mystery                290
# Adventure,Thriller                     288
# Action,Animation,Fantasy               288
# Documentary,War                        287
# Music,Romance                          286
# Adventure,Comedy,Sci-Fi                275
# Adventure,Horror                       275
# Action,Romance,Thriller                274
# Fantasy,Sci-Fi                         273
# Drama,Fantasy,Thriller                 269
# Mystery,Sci-Fi,Thriller                266
# Adult                                  265
# Crime,Mystery,Romance                  265
# Mystery,Romance,Thriller               264
# Documentary,Drama,History              262
# Adventure,War                          261
# Crime,Romance,Thriller                 260
# Comedy,Romance,Sci-Fi                  260
# Biography,History                      258
# Adventure,Drama,Horror                 257
# Adventure,Horror,Thriller              256
# Crime,Drama,Family                     250
# Action,Comedy,Family                   250
# Horror,Romance                         250
# Animation,Drama                        248
# Documentary,History,War                247
# Crime,Drama,Musical                    247
# Crime,Drama,Fantasy                    245
# Comedy,Fantasy,Sci-Fi                  242
# Adventure,Comedy,Horror                242
# Drama,Family,Sport                     241
# Drama,Romance,Western                  237
# Family,Romance                         234
# Action,History                         233
# Fantasy,Horror,Sci-Fi                  233
# Action,Biography,Crime                 233
# Drama,Music,Musical                    229
# Comedy,Fantasy,Musical                 228
# Biography,Drama,Musical                226
# Action,Adventure,Biography             224
# Comedy,Documentary,Drama               224
# Action,Romance,Western                 223
# Drama,Family,Music                     222
# Animation,Drama,Family                 216
# Adventure,Drama,Sci-Fi                 214
# Adventure,Animation                    213
# Adventure,Fantasy,Horror               213
# Animation,Comedy,Fantasy               208
# Crime,Romance                          207
# Fantasy,Thriller                       204
# Adventure,Documentary                  203
# Drama,Family,History                   200
# Comedy,Romance,Thriller                198
# Animation,Drama,Fantasy                198
# Adventure,Comedy,Musical               194
# Comedy,Horror,Musical                  191
# Drama,Fantasy,Musical                  190
# Comedy,Crime,Musical                   186
# Drama,Family,Thriller                  185
# Comedy,Crime,Fantasy                   182
# Comedy,Mystery,Romance                 181
# Comedy,Drama,Western                   180
# Comedy,Family,Sci-Fi                   179
# Crime,Film-Noir,Mystery                178
# Drama,Film-Noir                        178
# Action,Drama,Music                     178
# History,War                            177
# Drama,History,Musical                  175
# Adventure,Mystery                      172
# Family,Fantasy,Musical                 171
# Family,Musical                         168
# Comedy,Family,Sport                    167
# Action,Crime,Sci-Fi                    166
# Comedy,Family,Music                    165
# Horror,Romance,Thriller                165
# Mystery,Sci-Fi                         164
# Documentary,Family                     164
# Comedy,Romance,War                     162
# Action,Animation,Crime                 162
# Mystery,Romance                        160
# Biography,Comedy                       156
# Animation,Sci-Fi                       155
# Adventure,Horror,Sci-Fi                155
# Crime,Drama,Sport                      154
# Adventure,Crime,Thriller               152
# Adventure,Family,Mystery               151
# Action,Mystery                         151
# Adventure,Crime,Mystery                151
# Adventure,Fantasy,Sci-Fi               150
# Animation,Fantasy                      149
# Action,Sport                           148
# Action,Comedy,Music                    148
# Adventure,Horror,Mystery               148
# Drama,Fantasy,Music                    147
# Adventure,Family,Sci-Fi                146
# Horror,Mystery,Romance                 144
# Drama,Family,Mystery                   141
# Action,Comedy,Musical                  140
# Biography,Drama,Thriller               136
# Adventure,Documentary,Drama            136
# Comedy,Music,Musical                   134
# Family,Sci-Fi                          133
# Comedy,Romance,Western                 132
# Romance,Sci-Fi                         132
# Drama,History,Music                    132
# Comedy,Crime,Music                     132
# Adventure,Drama,Music                  131
# Comedy,Musical,Western                 131
# Crime,Drama,War                        131
# Drama,Family,Western                   131
# Adventure,Fantasy,Romance              129
# Romance,War                            128
# Action,Mystery,Sci-Fi                  128
# Thriller,War                           128
# Biography,Comedy,Crime                 128
# Adventure,Drama,Musical                127
# Action,Comedy,Mystery                  127
# Crime,Documentary                      126
# Biography,Comedy,Documentary           125
# Drama,Film-Noir,Mystery                124
# Documentary,News                       122
# Family,Sport                           121
# Drama,Family,War                       120
# Action,Fantasy,Thriller                120
# Adventure,History,Romance              119
# Action,Thriller,War                    119
# Adventure,Comedy,Music                 119
# Adventure,Comedy,Western               119
# Drama,History,Western                  118
# Biography,Documentary,Sport            118
# Drama,Film-Noir,Thriller               116
# Documentary,History,Music              115
# Documentary,Horror                     115
# Documentary,Drama,Family               114
# Action,History,War                     113
# Action,Music,Western                   111
# Adventure,Biography,Documentary        111
# Adventure,Comedy,Mystery               110
# Fantasy,Mystery                        110
# Documentary,History,News               109
# Adventure,Animation,Sci-Fi             108
# Adventure,Mystery,Thriller             108
# Adventure,History,War                  107
# Adventure,Crime,Family                 105
# Animation,Family,Musical               104
# Documentary,Musical                    104
# Comedy,Sci-Fi,Thriller                 103
# Animation,Comedy,Sci-Fi                103
# Action,Comedy,Western                  103
# Action,Crime,Fantasy                   102
# Action,Music,Romance                   101
# Comedy,Fantasy,Music                   100
# Drama,Fantasy,History                   98
# Action,Family                           97
# History,Romance                         96
# Animation,Drama,Romance                 96
# Family,Western                          96
# Drama,History,Mystery                   96
# Crime,Family                            95
# Comedy,Musical,Sci-Fi                   95
# Action,Animation                        94
# Fantasy,Horror,Romance                  93
# Crime,Documentary,Drama                 93
# Drama,Music,Mystery                     91
# Adventure,Crime,Romance                 90
# Action,Comedy,Sport                     90
# Action,Family,Sci-Fi                    90
# Animation,Biography,Drama               90
# Horror,Western                          89
# Crime,Film-Noir,Thriller                89
# Drama,Film-Noir,Romance                 88
# Fantasy,Mystery,Sci-Fi                  88
# Adventure,Sci-Fi,Thriller               88
# Adventure,Comedy,Documentary            87
# Documentary,Drama,War                   87
# Comedy,Fantasy,Mystery                  86
# Crime,Sci-Fi,Thriller                   86
# Documentary,Drama,Music                 86
# Crime,Drama,Western                     84
# Crime,Sci-Fi                            84
# Adventure,Romance,Western               84
# Action,Adventure,Documentary            83
# Adventure,Comedy,History                82
# Crime,Drama,Sci-Fi                      81
# Drama,Thriller,Western                  80
# Crime,Horror,Sci-Fi                     80
# Adventure,Comedy,War                    80
# Action,Biography,History                79
# Drama,Mystery,War                       79
# Drama,History,Sport                     78
# Family,Mystery                          77
# Animation,Documentary                   77
# Action,Comedy,War                       77
# Biography,Music                         77
# Biography,Crime,Documentary             77
# Animation,Comedy,Crime                  76
# Adventure,Fantasy,Mystery               75
# Comedy,Family,Horror                    74
# Mystery,Western                         74
# Biography,Documentary,Family            74
# Adventure,Biography,History             74
# Animation,Biography,Documentary         73
# Adventure,Comedy,Thriller               73
# Action,Fantasy,Romance                  73
# Romance,Sport                           72
# Adventure,Musical                       72
# Comedy,Crime,Sci-Fi                     71
# Animation,Sport                         71
# Comedy,Horror,Music                     71
# Fantasy,Mystery,Romance                 71
# Drama,History,Horror                    71
# Crime,Fantasy,Horror                    69
# Animation,Comedy,Romance                69
# Biography,Drama,Mystery                 67
# Crime,Mystery,Sci-Fi                    67
# Adventure,Documentary,History           67
# Fantasy,Musical                         67
# Adventure,Documentary,Sport             67
# Adventure,Family,Western                67
# Action,Musical,Romance                  67
# Animation,Comedy,Musical                66
# Action,Adventure,Music                  66
# Biography,Musical                       65
# Drama,Musical,Thriller                  65
# Action,Documentary,Sport                64
# Crime,Western                           63
# Comedy,Mystery,Sci-Fi                   63
# Animation,Drama,Sport                   62
# Action,Documentary,Drama                62
# Comedy,Family,Western                   61
# Drama,Music,War                         61
# Documentary,Mystery                     61
# Adventure,Crime,Fantasy                 60
# Drama,Family,Sci-Fi                     60
# Animation,Crime,Drama                   60
# Adventure,Family,Romance                59
# Fantasy,Mystery,Thriller                59
# Horror,Musical                          59
# Fantasy,Sci-Fi,Thriller                 59
# Adventure,Biography,Comedy              58
# Biography,Drama,Fantasy                 58
# Animation,Horror                        57
# Horror,Romance,Sci-Fi                   56
# Action,Biography                        56
# Thriller,Western                        56
# Romance,Sci-Fi,Thriller                 55
# Adventure,Fantasy,Musical               55
# Action,Mystery,Romance                  55
# Biography,History,War                   55
# Action,Horror,Western                   55
# Comedy,Musical,War                      54
# Animation,Comedy,Horror                 54
# Crime,Horror,Romance                    53
# Film-Noir,Mystery                       53
# Action,Horror,Romance                   52
# Comedy,History,Romance                  52
# Documentary,Romance                     51
# Comedy,Family,Mystery                   51
# Comedy,Musical,Sport                    51
# Adventure,Documentary,Family            51
# Comedy,Musical,Mystery                  51
# Comedy,Documentary,Family               51
# Animation,Drama,Music                   51
# Documentary,Drama,Sport                 50
# Biography,Comedy,Music                  50
# Action,Musical                          49
# Drama,Musical,Mystery                   49
# Action,Biography,Documentary            49
# Crime,Fantasy,Mystery                   49
# Crime,Documentary,History               48
# Drama,Fantasy,War                       48
# Documentary,Family,History              48
# Adventure,Romance,War                   48
# Animation,Comedy,Music                  48
# Action,Comedy,History                   48
# Animation,Drama,Horror                  47
# Comedy,Documentary,Music                47
# Adventure,Fantasy,History               47
# Music,Musical                           47
# Adventure,Mystery,Romance               46
# Family,Fantasy,Horror                   46
# Comedy,Documentary,Musical              46
# Fantasy,Musical,Romance                 46
# Horror,Thriller,Western                 46
# Adventure,Animation,Crime               46
# Reality-TV                              45
# Adventure,Family,Musical                45
# War,Western                             45
# Musical,Western                         45
# Crime,Musical                           45
# Action,Animation,Horror                 44
# Drama,Music,Thriller                    44
# Drama,Sport,Thriller                    44
# Drama,Mystery,Western                   44
# Comedy,Crime,Sport                      44
# Adventure,Comedy,Sport                  44
# Biography,Drama,Horror                  43
# Action,Romance,War                      43
# Drama,Horror,Musical                    43
# Animation,Drama,History                 42
# Animation,Documentary,History           42
# Action,Fantasy,History                  42
# Family,Fantasy,Music                    42
# Family,Thriller                         42
# Action,Adventure,Musical                41
# Action,Family,Fantasy                   41
# Biography,War                           41
# Drama,Horror,Music                      41
# Action,Crime,Musical                    41
# History,Western                         41
# Comedy,History,Musical                  41
# Animation,Fantasy,Horror                40
# Adventure,Romance,Thriller              40
# Action,Documentary                      39
# Animation,Drama,Sci-Fi                  39
# Family,Fantasy,Mystery                  39
# Adventure,War,Western                   39
# Comedy,Music,Sport                      39
# Action,Romance,Sci-Fi                   38
# Horror,Music                            38
# Family,Musical,Romance                  38
# Comedy,Crime,Film-Noir                  38
# Action,History,Romance                  38
# Adventure,Music,Romance                 38
# Action,Thriller,Western                 37
# Family,Music                            37
# Documentary,Drama,News                  37
# Action,Animation,Family                 37
# Sci-Fi,Western                          37
# Action,Sci-Fi,Western                   37
# Musical,Thriller                        36
# Drama,Musical,War                       36
# Family,Fantasy,Romance                  36
# Adventure,Animation,Biography           36
# Family,Fantasy,Sci-Fi                   36
# Drama,War,Western                       36
# Horror,War                              36
# Adventure,Drama,Sport                   36
# Action,History,Thriller                 36
# Adventure,Mystery,Sci-Fi                35
# Animation,Thriller                      35
# Musical,Romance,Thriller                35
# Action,Crime,Sport                      34
# Animation,Musical                       34
# Crime,Thriller,Western                  34
# Comedy,Fantasy,Thriller                 34
# Fantasy,Music,Romance                   33
# Action,Sci-Fi,War                       33
# Family,Horror                           33
# Comedy,Documentary,History              33
# Documentary,Thriller                    33
# Adventure,Horror,Romance                33
# Action,Crime,Western                    33
# Biography,Comedy,Musical                33
# Biography,Western                       33
# Horror,Music,Thriller                   32
# Drama,Sci-Fi,War                        32
# Fantasy,Romance,Thriller                32
# Musical,Sci-Fi                          31
# Comedy,Music,Western                    31
# Family,War                              31
# Action,Fantasy,Mystery                  31
# Adventure,Crime,Sci-Fi                  31
# Fantasy,Music                           31
# Documentary,Drama,Romance               31
# Action,Musical,Thriller                 31
# Drama,Music,Sci-Fi                      30
# Action,Fantasy,Musical                  30
# Comedy,Documentary,Romance              30
# Crime,Film-Noir,Romance                 29
# Animation,Fantasy,Music                 29
# Fantasy,History                         29
# Drama,History,Sci-Fi                    29
# Adventure,Crime,Horror                  29
# Adventure,Animation,Horror              28
# Adventure,Sport                         28
# Adventure,Biography,Crime               28
# Drama,Film-Noir,Sport                   28
# Action,Romance,Sport                    28
# History,Musical                         28
# Animation,Documentary,Drama             28
# Biography,Documentary,News              28
# Crime,History,Thriller                  28
# History,Thriller                        28
# Biography,Comedy,Romance                27
# Animation,Fantasy,Mystery               27
# Crime,History                           27
# Documentary,Sci-Fi                      27
# Documentary,Drama,Fantasy               27
# Animation,Biography,Comedy              27
# Comedy,Music,Sci-Fi                     27
# Biography,Comedy,History                27
# Adventure,Documentary,Music             27
# Biography,Sport                         27
# Animation,Fantasy,Musical               27
# Comedy,Documentary,Horror               26
# Biography,Documentary,War               26
# Animation,Fantasy,Sci-Fi                26
# History,Horror                          26
# Fantasy,History,Romance                 26
# Biography,Romance                       25
# Crime,Horror,Musical                    25
# Action,Biography,Comedy                 25
# Comedy,Family,Thriller                  25
# Documentary,Music,Musical               25
# Adventure,Crime,Western                 25
# Animation,History                       25
# Horror,Thriller,War                     25
# Drama,Family,Horror                     25
# Documentary,Family,Music                24
# Fantasy,Western                         24
# Action,Crime,Family                     24
# Action,Comedy,Documentary               24
# Drama,Horror,Western                    24
# Adult,Drama                             24
# Fantasy,Romance,Sci-Fi                  24
# Horror,Mystery,Western                  24
# Documentary,Drama,Mystery               24
# Crime,Music,Mystery                     24
# Film-Noir,Thriller                      24
# Animation,Drama,Mystery                 24
# Adventure,Biography                     24
# Drama,Sport,War                         24
# Comedy,History,War                      24
# Documentary,History,Sport               24
# Music,Western                           23
# Biography,Comedy,Horror                 23
# Action,Sport,Thriller                   23
# Animation,Family,Sci-Fi                 23
# Comedy,Family,History                   23
# Action,Music                            22
# Animation,Horror,Mystery                22
# Action,Crime,History                    22
# Animation,Drama,War                     22
# Crime,Fantasy                           21
# Action,Horror,War                       21
# Music,Romance,Western                   21
# Family,Music,Romance                    21
# Musical,Romance,Western                 21
# Animation,Family,History                21
# Crime,War                               21
# History,War,Western                     21
# Adventure,Documentary,News              21
# Drama,Horror,War                        21
# Documentary,Fantasy                     21
# Horror,Music,Sci-Fi                     20
# Adventure,Family,Horror                 20
# Biography,Crime,Thriller                20
# Comedy,Crime,History                    20
# Crime,Music,Thriller                    20
# Action,Crime,Music                      20
# Mystery,Romance,Sci-Fi                  20
# Comedy,Fantasy,Sport                    20
# Animation,Drama,Thriller                20
# History,Horror,Thriller                 20
# Music,Musical,Romance                   20
# Adventure,Musical,Romance               20
# Film-Noir,Mystery,Thriller              20
# Adventure,Romance,Sci-Fi                20
# Biography,Documentary,Musical           20
# Comedy,Music,War                        20
# Biography,Drama,Western                 20
# Comedy,Fantasy,History                  20
# Crime,Musical,Romance                   20
# Adventure,Family,Sport                  20
# Comedy,Crime,Western                    20
# Animation,Drama,Musical                 19
# Comedy,Music,Mystery                    19
# History,Musical,Romance                 19
# Music,Mystery,Thriller                  19
# Drama,Short                             19
# Adventure,Thriller,Western              19
# Animation,Sci-Fi,War                    19
# Drama,Fantasy,Western                   19
# Adventure,Drama,Film-Noir               18
# Animation,Sci-Fi,Thriller               18
# Musical,Mystery,Thriller                18
# Horror,Music,Mystery                    18
# Action,Horror,Sport                     18
# Music,Romance,War                       18
# Animation,Family,Western                18
# Crime,Family,Musical                    18
# Documentary,Western                     18
# Crime,Documentary,Mystery               17
# Action,Crime,Documentary                17
# Mystery,Thriller,War                    17
# Adventure,Animation,History             17
# Action,Family,Thriller                  17
# Animation,Horror,Sci-Fi                 17
# Crime,History,Mystery                   17
# Biography,Crime,Western                 17
# Action,Documentary,History              17
# Adventure,Mystery,Western               17
# Drama,Film-Noir,Music                   16
# History,Thriller,War                    16
# Adventure,Fantasy,Thriller              16
# Musical,Romance,War                     16
# Documentary,Drama,Thriller              16
# Biography,Family                        16
# Biography,Music,Romance                 16
# Comedy,Family,War                       16
# Musical,Mystery,Romance                 16
# Action,Sci-Fi,Sport                     16
# Animation,Fantasy,Romance               16
# Animation,Music                         16
# Action,Mystery,Western                  16
# Drama,Musical,Western                   16
# Adventure,Family,History                16
# Adventure,History,Musical               16
# Action,Crime,War                        16
# Documentary,Drama,Horror                16
# Crime,Musical,Mystery                   16
# Adventure,Crime,History                 16
# Biography,Crime,Horror                  16
# Animation,Mystery,Sci-Fi                16
# Drama,Fantasy,Sport                     16
# Romance,Thriller,War                    16
# Animation,Comedy,Documentary            16
# Sport,Thriller                          16
# History,Romance,Western                 16
# Adult,Comedy                            15
# Crime,Musical,Thriller                  15
# Biography,History,Romance               15
# Comedy,Music,Thriller                   15
# Documentary,Horror,Thriller             15
# Biography,Crime                         15
# Family,Musical,Mystery                  15
# Animation,Mystery,Thriller              15
# Comedy,Drama,Reality-TV                 15
# Action,Musical,War                      15
# Comedy,Short                            14
# Animation,Comedy,History                14
# Action,Family,Western                   14
# Action,Family,Mystery                   14
# Adventure,Music,Western                 14
# Music,Sci-Fi                            14
# Comedy,Thriller,War                     14
# Crime,Family,Mystery                    14
# Film-Noir,Horror,Mystery                14
# Biography,Crime,History                 14
# Musical,Mystery                         14
# Adventure,Mystery,War                   14
# Biography,Fantasy                       14
# Crime,Music                             13
# Musical,War                             13
# Comedy,History,Music                    13
# History,Sci-Fi                          13
# Documentary,Drama,Musical               13
# Documentary,Horror,Mystery              13
# Adventure,Biography,Western             12
# Action,History,Western                  12
# Adventure,Biography,Romance             12
# Action,Family,Horror                    12
# Animation,Biography,History             12
# Drama,Mystery,Sport                     12
# Comedy,Horror,Western                   12
# Family,Fantasy,Western                  12
# History,Romance,War                     12
# Crime,Film-Noir                         12
# Biography,History,Western               12
# Action,War,Western                      12
# Fantasy,Horror,Western                  12
# Action,Family,Romance                   12
# Adventure,Music,Sci-Fi                  12
# Adventure,History,Mystery               12
# Mystery,Thriller,Western                12
# History,Mystery,Thriller                12
# Fantasy,Music,Musical                   12
# Crime,Music,Romance                     12
# Animation,Crime,Documentary             12
# Action,Drama,Film-Noir                  12
# Biography,Horror                        12
# Adventure,Animation,Musical             12
# Animation,Family,Music                  12
# Action,Crime,Film-Noir                  12
# Fantasy,Horror,Musical                  12
# Family,Horror,Mystery                   12
# Comedy,Horror,Sport                     12
# Crime,Fantasy,Thriller                  12
# Action,Animation,Music                  12
# Action,Animation,Sport                  12
# Action,Family,Musical                   11
# Adventure,Crime,War                     11
# Crime,Romance,Sci-Fi                    11
# Drama,Sci-Fi,Sport                      11
# Adult,Romance                           11
# Comedy,Documentary,Sport                11
# Animation,Crime,Mystery                 11
# Action,Biography,Western                11
# Animation,Biography,Family              11
# Reality-TV,Sport                        11
# Biography,Thriller                      11
# Adventure,History,Sci-Fi                11
# Documentary,Drama,Reality-TV            10
# Adventure,Music                         10
# Adventure,Documentary,Romance           10
# Documentary,Family,News                 10
# Animation,Biography,Crime               10
# Mystery,War                              9
# Biography,Documentary,Romance            9
# Crime,Documentary,News                   9
# Romance,War,Western                      9
# Documentary,History,Musical              9
# Animation,Horror,Music                   9
# Biography,Family,History                 9
# Comedy,Horror,War                        9
# Horror,Sci-Fi,Western                    9
# Adult,Romance,Thriller                   9
# Adventure,Family,Music                   9
# History,Romance,Thriller                 9
# Documentary,Fantasy,Mystery              9
# Animation,Biography                      9
# Comedy,Documentary,News                  9
# Biography,Music,Musical                  9
# Fantasy,Musical,Sci-Fi                   9
# Animation,Comedy,Sport                   9
# Biography,Romance,War                    9
# Drama,Musical,Sci-Fi                     8
# Animation,Fantasy,Thriller               8
# History,Sport                            8
# Horror,Sport,Thriller                    8
# Biography,History,Thriller               8
# Comedy,History,Horror                    8
# Action,Adventure,Sport                   8
# Family,Music,Musical                     8
# Action,Animation,Romance                 8
# Family,Mystery,Thriller                  8
# Biography,Family,Sport                   8
# Biography,Comedy,Family                  8
# Action,Documentary,Fantasy               8
# Action,Animation,Mystery                 8
# Documentary,History,Thriller             8
# Animation,Fantasy,History                8
# Biography,Documentary,Fantasy            8
# Documentary,Reality-TV                   8
# Family,Horror,Thriller                   8
# Family,Sci-Fi,Western                    8
# Music,Romance,Thriller                   8
# Documentary,Music,War                    8
# Documentary,History,Mystery              8
# Action,Fantasy,War                       8
# Adventure,Documentary,Mystery            8
# Crime,Romance,Western                    8
# Action,Biography,Thriller                8
# Documentary,Family,Sport                 8
# Adventure,Biography,War                  8
# Crime,Horror,Music                       8
# Mystery,Romance,Sport                    8
# Family,Horror,Sci-Fi                     8
# Adventure,History,Thriller               8
# History,Music,Romance                    8
# Horror,Sport                             8
# Adventure,Biography,Family               8
# Musical,Romance,Sport                    8
# Adventure,Horror,Western                 8
# Adventure,Family,Thriller                8
# History,Mystery                          8
# Fantasy,History,Horror                   8
# Adventure,Sci-Fi,Western                 8
# Biography,Musical,Romance                8
# Biography,History,Music                  8
# Animation,Family,Romance                 8
# Drama,Music,Sport                        8
# Fantasy,History,War                      8
# Comedy,Drama,Film-Noir                   8
# Drama,Sport,Western                      8
# Drama,Music,Western                      8
# Drama,Musical,Sport                      8
# Biography,Family,Musical                 8
# Documentary,Fantasy,Horror               8
# Mystery,Romance,Western                  8
# Adventure,Fantasy,War                    8
# Music,Romance,Sport                      8
# Film-Noir,Horror,Thriller                8
# Reality-TV,Sci-Fi                        7
# Documentary,Mystery,Thriller             7
# Animation,Romance                        7
# Talk-Show                                7
# Biography,Fantasy,History                7
# Animation,Family,Sport                   7
# Action,Fantasy,Western                   7
# News                                     7
# Drama,News,War                           7
# Adventure,Documentary,Western            7
# Action,Comedy,Short                      7
# Documentary,Music,Sport                  7
# Biography,Comedy,Fantasy                 6
# Biography,History,Mystery                6
# Adventure,Musical,Sci-Fi                 6
# Family,Fantasy,War                       6
# Biography,Documentary,Horror             6
# Documentary,Mystery,Sci-Fi               6
# Documentary,Drama,Sci-Fi                 6
# Animation,Documentary,War                6
# Mystery,Romance,War                      6
# History,Horror,Mystery                   6
# Documentary,History,Romance              6
# Family,Music,Sport                       6
# Documentary,History,Western              6
# Documentary,History,Horror               6
# Documentary,History,Reality-TV           6
# Action,Adult,Crime                       6
# Action,Documentary,War                   6
# Comedy,Talk-Show                         6
# Animation,Biography,Fantasy              5
# Adult,Crime,Horror                       5
# Family,Fantasy,History                   5
# Action,Animation,History                 5
# Music,Mystery                            5
# Animation,Horror,Thriller                5
# Biography,Comedy,Sci-Fi                  5
# Romance,Sport,Western                    5
# Comedy,Documentary,Sci-Fi                5
# Adventure,Documentary,Reality-TV         5
# Comedy,Crime,Documentary                 5
# Film-Noir,Horror,Sci-Fi                  5
# Action,Adult,Sci-Fi                      5
# Animation,Documentary,Music              5
# Comedy,Fantasy,Western                   4
# Animation,History,Musical                4
# Film-Noir,Western                        4
# Action,History,Horror                    4
# Drama,Fantasy,Film-Noir                  4
# Adventure,Film-Noir                      4
# Comedy,Thriller,Western                  4
# Adventure,Musical,Mystery                4
# Drama,Sci-Fi,Western                     4
# Biography,Drama,News                     4
# Crime,Film-Noir,Sport                    4
# Animation,Romance,Sci-Fi                 4
# Fantasy,Mystery,Western                  4
# Documentary,Horror,Sci-Fi                4
# Animation,Music,Romance                  4
# Fantasy,Horror,Music                     4
# Comedy,War,Western                       4
# Documentary,News,Reality-TV              4
# Adventure,Romance,Sport                  4
# Family,Musical,Sport                     4
# Comedy,History,Mystery                   4
# Documentary,Music,Sci-Fi                 4
# Thriller,War,Western                     4
# Documentary,History,Sci-Fi               4
# Crime,Family,Thriller                    4
# Animation,History,Romance                4
# History,Sci-Fi,Thriller                  4
# Fantasy,Musical,Mystery                  4
# Adventure,History,Western                4
# Adventure,Family,War                     4
# Animation,Western                        4
# Family,Mystery,Sport                     4
# Biography,Thriller,Western               4
# Comedy,Documentary,Mystery               4
# Biography,Crime,Mystery                  4
# Adventure,Documentary,Horror             4
# Horror,Sci-Fi,War                        4
# History,Sport,Thriller                   4
# Comedy,Sport,Thriller                    4
# Comedy,History,Sport                     4
# Family,Horror,War                        4
# Biography,Thriller,War                   4
# Crime,Mystery,Western                    4
# Sport,War                                4
# Musical,Mystery,Sci-Fi                   4
# Crime,Fantasy,History                    4
# Family,Sci-Fi,Thriller                   4
# Family,Musical,Sci-Fi                    4
# Biography,Crime,Film-Noir                4
# Documentary,Music,Western                4
# Action,Animation,Biography               4
# Biography,Documentary,Thriller           4
# Comedy,Drama,News                        4
# Adventure,Sci-Fi,War                     4
# Crime,History,Musical                    4
# Family,History,War                       4
# Crime,History,Horror                     4
# Action,Musical,Sci-Fi                    4
# Documentary,Fantasy,History              4
# Biography,Fantasy,Horror                 4
# Biography,Drama,Film-Noir                4
# Action,Film-Noir,Mystery                 4
# Comedy,Sport,Western                     4
# Sci-Fi,Short                             4
# Documentary,News,Thriller                4
# Comedy,Sci-Fi,Western                    4
# Comedy,Sci-Fi,Sport                      4
# Animation,Music,Musical                  4
# Adult,Comedy,Fantasy                     4
# Animation,History,Music                  4
# Horror,Reality-TV,Sci-Fi                 4
# Drama,Mystery,News                       4
# Family,Horror,Romance                    4
# Action,Crime,Short                       4
# Comedy,Film-Noir,Mystery                 4
# Biography,Family,Western                 4
# Adventure,Animation,Western              4
# Action,History,Mystery                   4
# Crime,Thriller,War                       4
# Biography,Romance,Western                4
# Horror,Musical,Sci-Fi                    4
# Animation,Crime,Music                    4
# Adult,Sci-Fi                             4
# Crime,Sport                              4
# Action,Music,Sci-Fi                      4
# Adult,Crime,Thriller                     4
# History,Romance,Sci-Fi                   4
# Action,Animation,Western                 4
# Mystery,Sport                            4
# Adventure,Crime,Musical                  4
# Biography,Music,Mystery                  4
# Music,Musical,Sci-Fi                     4
# Music,Romance,Sci-Fi                     4
# Documentary,Horror,Musical               4
# Sci-Fi,War                               4
# Action,Animation,Thriller                4
# Comedy,Mystery,Sport                     4
# Action,Family,Sport                      4
# Adventure,Animation,Mystery              4
# Music,Thriller                           4
# Documentary,Fantasy,Music                4
# Music,Sci-Fi,Thriller                    4
# Action,Musical,Western                   4
# Adventure,Fantasy,Western                4
# Adult,Crime,Drama                        4
# Family,History,Musical                   4
# Adventure,Animation,Romance              4
# Film-Noir,Horror                         4
# Comedy,Sport,War                         4
# Musical,Sci-Fi,Thriller                  4
# Animation,Crime,Fantasy                  4
# Action,Musical,Mystery                   4
# Family,Fantasy,Sport                     4
# Animation,Comedy,Western                 4
# Crime,Horror,Western                     4
# Fantasy,Sport                            4
# Drama,Mystery,Short                      4
# Family,Mystery,Sci-Fi                    4
# Fantasy,Horror,War                       4
# Adventure,Musical,Western                4
# Horror,Romance,Western                   4
# Adventure,Crime,Sport                    4
# Drama,News,Thriller                      4
# Biography,Comedy,Mystery                 4
# Comedy,Drama,Short                       4
# Crime,Fantasy,Romance                    4
# Crime,Documentary,Music                  4
# Documentary,Music,Romance                4
# Adult,Comedy,Drama                       4
# Horror,Music,Musical                     4
# Animation,Comedy,War                     4
# Musical,Sport                            4
# Comedy,Crime,War                         4
# Adventure,Comedy,Film-Noir               4
# Adult,Drama,Romance                      4
# Adventure,Musical,War                    4
# Drama,Film-Noir,Horror                   4
# Film-Noir,Mystery,Romance                4
# Comedy,Musical,Thriller                  4
# History,Music                            4
# Crime,Documentary,War                    4
# Documentary,Music,News                   4
# Adventure,Film-Noir,Romance              4
# Adventure,Crime,Film-Noir                4
# Comedy,Sci-Fi,War                        4
# Film-Noir,Romance,Thriller               4
# Animation,Documentary,Family             4
# Family,History,Sci-Fi                    4
# Documentary,Horror,Music                 4
# Animation,Comedy,Mystery                 4
# Adult,Crime                              4
# Animation,Crime,Sci-Fi                   4
# Horror,Reality-TV                        4
# Comedy,Film-Noir                         4
# Drama,Horror,Sport                       4
# Comedy,Documentary,Reality-TV            3
# Horror,Musical,Romance                   3
# Comedy,News                              3
# Comedy,Documentary,Western               3
# Animation,Musical,Romance                3
# Documentary,News,Sport                   3
# Biography,Sci-Fi                         3
# Biography,Documentary,Western            3
# Documentary,Music,Mystery                3
# Adventure,Crime,Documentary              3
# Drama,Reality-TV                         3
# Crime,Documentary,Sport                  2
# Crime,Documentary,Family                 2
# Crime,Documentary,Fantasy                2
# Documentary,Thriller,War                 2
# Documentary,Family,Fantasy               2
# Documentary,Romance,War                  2
# Adventure,News                           2
# Adventure,Animation,Music                2
# Adventure,Documentary,Thriller           2
# Documentary,Family,Western               2
# Comedy,Documentary,Fantasy               2
# Documentary,Family,Musical               2
# Documentary,Family,Romance               2
# Biography,Documentary,Sci-Fi             2
# Animation,Horror,Romance                 2
# Animation,History,War                    2
# Biography,Comedy,War                     2
# Adult,Documentary                        2
# Documentary,War,Western                  1
# Documentary,Family,War                   1
# Short,Sport                              1
# Adventure,Animation,Documentary          1
# Documentary,Short                        1
# Animation,Biography,Music                1
# Adventure,Documentary,War                1
# Documentary,Mystery,News                 1
# Animation,Documentary,Fantasy            1
# Action,Documentary,Horror                1
# Crime,Documentary,Thriller               1
# Documentary,Drama,Western                1
# Crime,Documentary,Reality-TV             1
# Music,Reality-TV                         1
# Documentary,Fantasy,Sci-Fi               1
# Adventure,Documentary,Fantasy            1
# Short                                    1
# Comedy,Documentary,Thriller              1
# Animation,War                            1
# Documentary,Mystery,Sport                1
# Action,Documentary,News                  1
# Documentary,Sport,Western                1
# Animation,Documentary,Musical            1
# Adventure,Documentary,Sci-Fi             1
# Biography,Documentary,Mystery            1
# Comedy,Documentary,War                   1
# Name: count, dtype: int64

# %%
# Importante: ignora maiúsculas/minúsculas para garantir mais abrangência
filtro_movies_guerra = df_movies['genero'].str.contains('War', case=False, na=False)

# Quantidade total de filmes com 'War' no genero no movies.csv
print(f"🎯 Total de filmes de guerra no CSV movies: {filtro_movies_guerra.sum()}")
# Out:
# 🎯 Total de filmes de guerra no CSV movies: 22689
